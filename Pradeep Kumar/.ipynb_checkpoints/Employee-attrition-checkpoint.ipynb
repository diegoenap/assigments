# %%
# loading the libraries.
# Section must be included at the beginning of each new notebook. Remember to change the app name. 
# If you're using VirtualBox, change the below to '/home/user/spark-2.1.1-bin-hadoop2.7'
import findspark
findspark.init('/home/user/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf
spark = SparkSession.builder.appName('empoyee_attrition').getOrCreate()

# %%
# Reading the data
emp = spark.read.csv('Employee-Attrition.csv',header=True,inferSchema=True)
emp.cache()
# Out:
# DataFrame[Age: int, Attrition: string, BusinessTravel: string, DailyRate: int, Department: string, DistanceFromHome: int, Education: int, EducationField: string, EmployeeCount: int, EmployeeNumber: int, EnvironmentSatisfaction: int, Gender: string, HourlyRate: int, JobInvolvement: int, JobLevel: int, JobRole: string, JobSatisfaction: int, MaritalStatus: string, MonthlyIncome: int, MonthlyRate: int, NumCompaniesWorked: int, Over18: string, OverTime: string, PercentSalaryHike: int, PerformanceRating: int, RelationshipSatisfaction: int, StandardHours: int, StockOptionLevel: int, TotalWorkingYears: int, TrainingTimesLastYear: int, WorkLifeBalance: int, YearsAtCompany: int, YearsInCurrentRole: int, YearsSinceLastPromotion: int, YearsWithCurrManager: int]

# %%
# data exploration
# df.show() doesn't show the data cleanly.
# Import pandas.
import pandas as pd

# Take the first five rows of data, and visualise.
pd.DataFrame(emp.take(5), columns=emp.columns)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# 0          ...                                  1            80
# 1          ...                                  4            80
# 2          ...                                  2            80
# 3          ...                                  3            80
# 4          ...                                  4            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0               1
# 1                 1                 10                      3               3
# 2                 0                  7                      3               3
# 3                 0                  8                      3               3
# 4                 1                  6                      3               3
#
#    YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                  4                        0
# 1              10                  7                        1
# 2               0                  0                        0
# 3               8                  7                        3
# 4               2                  2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
# visualising the schema at a high level data structure
emp.printSchema()
# Out:
# root
#  |-- Age: integer (nullable = true)
#  |-- Attrition: string (nullable = true)
#  |-- BusinessTravel: string (nullable = true)
#  |-- DailyRate: integer (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- DistanceFromHome: integer (nullable = true)
#  |-- Education: integer (nullable = true)
#  |-- EducationField: string (nullable = true)
#  |-- EmployeeCount: integer (nullable = true)
#  |-- EmployeeNumber: integer (nullable = true)
#  |-- EnvironmentSatisfaction: integer (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- HourlyRate: integer (nullable = true)
#  |-- JobInvolvement: integer (nullable = true)
#  |-- JobLevel: integer (nullable = true)
#  |-- JobRole: string (nullable = true)
#  |-- JobSatisfaction: integer (nullable = true)
#  |-- MaritalStatus: string (nullable = true)
#  |-- MonthlyIncome: integer (nullable = true)
#  |-- MonthlyRate: integer (nullable = true)
#  |-- NumCompaniesWorked: integer (nullable = true)
#  |-- Over18: string (nullable = true)
#  |-- OverTime: string (nullable = true)
#  |-- PercentSalaryHike: integer (nullable = true)
#  |-- PerformanceRating: integer (nullable = true)
#  |-- RelationshipSatisfaction: integer (nullable = true)
#  |-- StandardHours: integer (nullable = true)
#  |-- StockOptionLevel: integer (nullable = true)
#  |-- TotalWorkingYears: integer (nullable = true)
#  |-- TrainingTimesLastYear: integer (nullable = true)
#  |-- WorkLifeBalance: integer (nullable = true)
#  |-- YearsAtCompany: integer (nullable = true)
#  |-- YearsInCurrentRole: integer (nullable = true)
#  |-- YearsSinceLastPromotion: integer (nullable = true)
#  |-- YearsWithCurrManager: integer (nullable = true)

# %%
# checking missing values (count), mean, stddev
emp.describe().toPandas().transpose()
# Out:
#                               0                   1                    2  \
# summary                   count                mean               stddev
# Age                        1470  36.923809523809524    9.135373489136729
# Attrition                  1470                None                 None
# BusinessTravel             1470                None                 None
# DailyRate                  1470   802.4857142857143   403.50909994352804
# Department                 1470                None                 None
# DistanceFromHome           1470    9.19251700680272     8.10686443566608
# Education                  1470   2.912925170068027   1.0241649445978718
# EducationField             1470                None                 None
# EmployeeCount              1470                 1.0                  0.0
# EmployeeNumber             1470   1024.865306122449    602.0243348474752
# EnvironmentSatisfaction    1470   2.721768707482993   1.0930822146350003
# Gender                     1470                None                 None
# HourlyRate                 1470   65.89115646258503   20.329427593996176
# JobInvolvement             1470  2.7299319727891156   0.7115611429632297
# JobLevel                   1470  2.0639455782312925   1.1069398989351202
# JobRole                    1470                None                 None
# JobSatisfaction            1470  2.7285714285714286   1.1028461230547213
# MaritalStatus              1470                None                 None
# MonthlyIncome              1470   6502.931292517007    4707.956783097992
# MonthlyRate                1470  14313.103401360544    7117.786044059972
# NumCompaniesWorked         1470  2.6931972789115646   2.4980090060707463
# Over18                     1470                None                 None
# OverTime                   1470                None                 None
# PercentSalaryHike          1470  15.209523809523809   3.6599377165396385
# PerformanceRating          1470  3.1537414965986397  0.36082352460434397
# RelationshipSatisfaction   1470  2.7122448979591836   1.0812088864403517
# StandardHours              1470                80.0                  0.0
# StockOptionLevel           1470  0.7938775510204081   0.8520766679308381
# TotalWorkingYears          1470  11.279591836734694    7.780781675514995
# TrainingTimesLastYear      1470  2.7993197278911564   1.2892706207958466
# WorkLifeBalance            1470  2.7612244897959184   0.7064758297141507
# YearsAtCompany             1470  7.0081632653061225    6.126525152403571
# YearsInCurrentRole         1470   4.229251700680272    3.623137034670627
# YearsSinceLastPromotion    1470  2.1877551020408164   3.2224302791379693
# YearsWithCurrManager       1470    4.12312925170068   3.5681361205404363
#
#                                                   3                     4
# summary                                         min                   max
# Age                                              18                    60
# Attrition                                        No                   Yes
# BusinessTravel                           Non-Travel         Travel_Rarely
# DailyRate                                       102                  1499
# Department                          Human Resources                 Sales
# DistanceFromHome                                  1                    29
# Education                                         1                     5
# EducationField                      Human Resources      Technical Degree
# EmployeeCount                                     1                     1
# EmployeeNumber                                    1                  2068
# EnvironmentSatisfaction                           1                     4
# Gender                                       Female                  Male
# HourlyRate                                       30                   100
# JobInvolvement                                    1                     4
# JobLevel                                          1                     5
# JobRole                   Healthcare Representative  Sales Representative
# JobSatisfaction                                   1                     4
# MaritalStatus                              Divorced                Single
# MonthlyIncome                                  1009                 19999
# MonthlyRate                                    2094                 26999
# NumCompaniesWorked                                0                     9
# Over18                                            Y                     Y
# OverTime                                         No                   Yes
# PercentSalaryHike                                11                    25
# PerformanceRating                                 3                     4
# RelationshipSatisfaction                          1                     4
# StandardHours                                    80                    80
# StockOptionLevel                                  0                     3
# TotalWorkingYears                                 0                    40
# TrainingTimesLastYear                             0                     6
# WorkLifeBalance                                   1                     4
# YearsAtCompany                                    0                    40
# YearsInCurrentRole                                0                    18
# YearsSinceLastPromotion                           0                    15
# YearsWithCurrManager                              0                    17

# %%
# We can use group by and count to find out how many data points we have for each class in our predictor.

emp.groupby('Attrition').count().toPandas()
# Out:
#   Attrition  count
# 0        No   1233
# 1       Yes    237

# %%
# List of problems: Resolve these problems
# Problmes found on comparing printschema and df.describe, using groupby
# 1. we can see some values none and comparing with the print schema we found that they are string values which need to be converted into integer
# 2. it is good we have no missing values. 
pdEmp = emp.toPandas()

# %%
# to know the rows and the column in dataset.
pdEmp.shape
# Out:
# (1470, 35)

# %%
# Reordering the dataset moving the targert variable "Attrition" to end.
#emp.head()
#emp.head()
X = pdEmp.pop('Attrition')
pdEmp['Attrition'] = X
pdEmp.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction    ...     StandardHours  StockOptionLevel  \
# 0                        2    ...                80                 0
# 1                        3    ...                80                 1
# 2                        4    ...                80                 0
# 3                        4    ...                80                 0
# 4                        1    ...                80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                  4                        0                     5        Yes
# 1                  7                        1                     7         No
# 2                  0                        0                     0        Yes
# 3                  7                        3                     0         No
# 4                  2                        2                     2         No
#
# [5 rows x 35 columns]

# %%
# So, we have two main task 
# As we see in the data.head() below columns contains the same value and doesnot provide meaning to data.
# removing the columns which contains same values (“EmployeeCount”, “EmployeeNumber”, “Over18”, “StandardHours”) and are not useful.
pdEmp = pdEmp.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1)
pdEmp.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
pdEmp.shape
# Out:
# (1470, 31)

# %%
# Handling categorical variables.
# since we have only two unique values we can convert them to 0,1
pdEmp["Attrition"].unique()
pdEmp['Attrition'].value_counts()
pdEmp.loc[pdEmp['Attrition']=='No', 'Attrition'] = 0
pdEmp.loc[pdEmp['Attrition']=='Yes', 'Attrition'] = 1

# %%
# %matplotlib inline
pdEmp['Attrition'].hist(bins=50)

# %%
# checking other categorical variable
# we can see there are only 3 unique values exists variable
# convert categorical variables(“Gender”, “BusinessTravel”, “Department”, “EducationField”, “JobRole”, “MaritalStatus”, “OverTime”) to numerical
# catgorising the business travel by employee
pdEmp['BusinessTravel'].unique()
pdEmp['pdEmpb_Travel_Rarely']=0
pdEmp['pdEmpb_Travel_Frequently']=0
pdEmp['pdEmpb_Non-Travel']=0

pdEmp.loc[pdEmp['BusinessTravel']=='Travel_Rarely','pdEmpb_Travel_Rarely'] = 1
pdEmp.loc[pdEmp['BusinessTravel']=='Travel_Frequently','pdEmpb_Travel_Frequently'] = 1
pdEmp.loc[pdEmp['BusinessTravel']=='Non-Travel','pdEmpb_Non-Travel'] = 1

# converting the education field and categorising.
pdEmp['Life_Sciences']=0
pdEmp['Medical']=0
pdEmp['Marketing']=0
pdEmp['Technical_Degree']=0
pdEmp['Education_Human_Resources']=0
pdEmp['Education_Other']=0

pdEmp.loc[pdEmp['EducationField']=='Life Sciences','Life_Sciences'] = 1
pdEmp.loc[pdEmp['EducationField']=='Medical','Medical'] = 1
pdEmp.loc[pdEmp['EducationField']=='Other','Education_Other'] = 1
pdEmp.loc[pdEmp['EducationField']=='Technical Degree','Technical_Degree'] = 1
pdEmp.loc[pdEmp['EducationField']=='Human Resources','Education_Human_Resources'] = 1
pdEmp.loc[pdEmp['EducationField']=='Marketing','Marketing'] = 1
# converting the department field
pdEmp['pdEmp_Sales']=0
pdEmp['pdEmp_R&D']=0
pdEmp['pdEmp_Dept_Human_Resources'] =0

pdEmp.loc[pdEmp['Department']=='Sales','pdEmp_Sales'] = 1
pdEmp.loc[pdEmp['Department']=='Research & Development','pdEmp_R&D'] = 1
pdEmp.loc[pdEmp['Department']=='Human Resources','pdEmp_Dept_Human_Resources'] = 1

# converting Geneder values from categorical to numerical
pdEmp.loc[pdEmp['Gender']=='Male','Gender'] = 1
pdEmp.loc[pdEmp['Gender']=='Female','Gender'] = 0

# converting on the basis of job role values to numeric fields
pdEmp['Research_Scientist']=0
pdEmp['Laboratory_Technician']=0
pdEmp['Sales_Executive']=0
pdEmp['Manufacturing_Director']=0
pdEmp['Healthcare_Representative']=0
pdEmp['Sales_Representative']=0
pdEmp['Research_Director']=0
pdEmp['Manager'] = 0
pdEmp['Job_Human_Resources'] = 0

pdEmp.loc[pdEmp['JobRole']=='Research Scientist','Research_Scientist'] = 1
pdEmp.loc[pdEmp['JobRole']=='Laboratory Technician','Laboratory_Technician'] = 1
pdEmp.loc[pdEmp['JobRole']=='Sales Executive','Sales_Executive'] = 1
pdEmp.loc[pdEmp['JobRole']=='Sales Representative','Sales_Representative'] = 1
pdEmp.loc[pdEmp['JobRole']=='Manufacturing Director','Manufacturing_Director'] = 1
pdEmp.loc[pdEmp['JobRole']=='Healthcare Representative','Healthcare_Representative'] = 1
pdEmp.loc[pdEmp['JobRole']=='Research Director','Research_Director'] = 1
pdEmp.loc[pdEmp['JobRole']=='Manager','Manager'] = 1
pdEmp.loc[pdEmp['JobRole']=='Human Resources','Job_Human_Resources'] = 1
pdEmp.head()
# converting Marital Satus of pdEmployee
pdEmp['Marital_single']=0
pdEmp['Marital_married']=0
pdEmp['Marital_divorced']=0

pdEmp.loc[pdEmp['MaritalStatus']=='Married','Marital_married'] = 1
pdEmp.loc[pdEmp['MaritalStatus']=='Single','Marital_single'] = 1
pdEmp.loc[pdEmp['MaritalStatus']=='Divorced','Marital_divorced'] = 1

# %%
pdEmp['OverTime'].unique()
# converting OverTime values from categorical to numerical
pdEmp.loc[pdEmp['OverTime']=='Yes','OverTime'] = 1
pdEmp.loc[pdEmp['OverTime']=='No','OverTime'] = 0

# %%
# removing the the extra columns
pdEmp = pdEmp.drop(['BusinessTravel','EducationField',
                        'Department','JobRole','MaritalStatus'],axis=1)

# %%
pdEmp.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'pdEmpb_Travel_Rarely',
#        'pdEmpb_Travel_Frequently', 'pdEmpb_Non-Travel', 'Life_Sciences',
#        'Medical', 'Marketing', 'Technical_Degree', 'Education_Human_Resources',
#        'Education_Other', 'pdEmp_Sales', 'pdEmp_R&D',
#        'pdEmp_Dept_Human_Resources', 'Research_Scientist',
#        'Laboratory_Technician', 'Sales_Executive', 'Manufacturing_Director',
#        'Healthcare_Representative', 'Sales_Representative',
#        'Research_Director', 'Manager', 'Job_Human_Resources', 'Marital_single',
#        'Marital_married', 'Marital_divorced'],
#       dtype='object')

# %%
# confirm checking if all the columns are conveted to int.
pdEmp.dtypes
# Out:
# Age                           int64
# DailyRate                     int64
# DistanceFromHome              int64
# Education                     int64
# EnvironmentSatisfaction       int64
# Gender                        int64
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobSatisfaction               int64
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# OverTime                      int64
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StockOptionLevel              int64
# TotalWorkingYears             int64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# Attrition                     int64
# pdEmpb_Travel_Rarely          int64
# pdEmpb_Travel_Frequently      int64
# pdEmpb_Non-Travel             int64
# Life_Sciences                 int64
# Medical                       int64
# Marketing                     int64
# Technical_Degree              int64
# Education_Human_Resources     int64
# Education_Other               int64
# pdEmp_Sales                   int64
# pdEmp_R&D                     int64
# pdEmp_Dept_Human_Resources    int64
# Research_Scientist            int64
# Laboratory_Technician         int64
# Sales_Executive               int64
# Manufacturing_Director        int64
# Healthcare_Representative     int64
# Sales_Representative          int64
# Research_Director             int64
# Manager                       int64
# Job_Human_Resources           int64
# Marital_single                int64
# Marital_married               int64
# Marital_divorced              int64
# dtype: object

# %%
# checking the histogram for each variable.
# %matplotlib inline
pdEmp.hist(bins=10,figsize=(15,30), layout=(11,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f776995eac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769916b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77698c71d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77698ee860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769898ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7769898f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776986fbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77698222b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77697c8940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77697f0fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f77697a06a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769749d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776977b400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769724a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77696d8160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f77696ff7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77696a8e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769657550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769680be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77696332b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f77695db940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769602fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77695b56a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776955cd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776950c400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7769533a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77694e8160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77694917f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77694b8e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776946a550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7769412be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77693c42b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77693ec940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769393fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77693446a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f776936ed30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776931f400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77692c6a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77692fa160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77692a07f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f776924ce80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776927c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769223be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77691d62b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769200940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f77691a6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77691586a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776917fd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769131400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77690d8a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f776908d160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f77690b37f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776905ce80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f776900f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7769035be0>]],
#       dtype=object)

# %%
# Resampling the data as data is not evenly distributed.
count_class_1, count_class_2 = pdEmp['Attrition'].value_counts()
# Divide by class
pdEmp_class_1 = pdEmp[pdEmp['Attrition'] == 0]
pdEmp_class_2 = pdEmp[pdEmp['Attrition'] == 1]
pdEmp_class_2.describe()

# Random under-smapling
pdEmp_class_1_under = pdEmp_class_1.sample(count_class_2)
pdEmp_class_1_under_data = pd.concat([pdEmp_class_1_under, pdEmp_class_2],axis=0)
print("Random Under-sampling")
print(pdEmp_class_1_under_data.Attrition.value_counts())




# Random over-sampling
pdEmp_class_2_over = pdEmp_class_2.sample(count_class_1, replace=True)
pdEmp_class_2_over_data = pd.concat([pdEmp_class_1, pdEmp_class_2_over], axis=0)

print('Random over-sampling:')
print(pdEmp_class_2_over_data.Attrition.value_counts())

pdEmp_class_2_over_data.Attrition.value_counts().plot(kind='bar', title='Count(Target)')
# Out:
# Random Under-sampling
# 1    237
# 0    237
# Name: Attrition, dtype: int64
# Random over-sampling:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %%
pdEmp_class_1_under_data.Attrition.value_counts().plot(kind='bar', title='Count(Target)')

# %%
# Now checking co-relation matrix to reduce the data.
pdEmp_class_1_under_data.corr()
# Out:
#                                  Age  DailyRate  DistanceFromHome  Education  \
# Age                         1.000000   0.042839         -0.000612   0.207815
# DailyRate                   0.042839   1.000000         -0.023391   0.031148
# DistanceFromHome           -0.000612  -0.023391          1.000000  -0.007641
# Education                   0.207815   0.031148         -0.007641   1.000000
# EnvironmentSatisfaction    -0.057323   0.024650         -0.026112  -0.038796
# Gender                      0.009181   0.027224          0.054072   0.010829
# HourlyRate                  0.066127   0.048240         -0.004646   0.063943
# JobInvolvement              0.080115   0.019497          0.049513   0.078870
# JobLevel                    0.483866   0.031256          0.042324   0.088204
# JobSatisfaction             0.025750   0.033096          0.000255  -0.024897
# MonthlyIncome               0.462287   0.026190         -0.005274   0.103664
# MonthlyRate                 0.066819  -0.100581         -0.000073  -0.009054
# NumCompaniesWorked          0.304574   0.074978         -0.074864   0.109112
# OverTime                   -0.053557   0.039872          0.112560  -0.042554
# PercentSalaryHike           0.018065  -0.003481          0.083155   0.030928
# PerformanceRating           0.028411   0.017886         -0.000469   0.011703
# RelationshipSatisfaction    0.051166   0.009751          0.021598   0.074709
# StockOptionLevel            0.137555   0.010159          0.059011   0.013031
# TotalWorkingYears           0.655603   0.063741         -0.051272   0.169553
# TrainingTimesLastYear      -0.033783  -0.047652         -0.018002  -0.059502
# WorkLifeBalance            -0.074190   0.002590          0.004230  -0.065507
# YearsAtCompany              0.340835  -0.040852         -0.026771   0.072981
# YearsInCurrentRole          0.266650  -0.015789         -0.037810   0.024686
# YearsSinceLastPromotion     0.188149  -0.015706          0.020821   0.080668
# YearsWithCurrManager        0.266230  -0.043432          0.012297   0.059405
# Attrition                                 -0.117934  0.056115    0.004557
# pdEmpb_Travel_Rarely                       0.045901  0.005699    0.009490
# pdEmpb_Travel_Frequently                  -0.024462 -0.045203   -0.063456
# pdEmpb_Non-Travel                         -0.039611  0.058709    0.079931
# Life_Sciences                             -0.060900 -0.014683    0.024166
# Medical                                   -0.012698 -0.030140    0.024446
# Marketing                                  0.030253 -0.049401   -0.038226
# Technical_Degree                          -0.041759  0.080460    0.004086
# Education_Human_Resources                 -0.002783 -0.008531   -0.022298
# Education_Other                            0.168350  0.061753   -0.035631
# pdEmp_Sales                                0.042095 -0.060832   -0.027383
# pdEmp_R&D                                 -0.032908  0.062147    0.036891
# pdEmp_Dept_Human_Resources                -0.021642 -0.006807   -0.026335
# Research_Scientist                         0.002238  0.050977    0.065660
# Laboratory_Technician                     -0.006610  0.119456   -0.031371
# Sales_Executive                            0.029094  0.006253   -0.029350
# Manufacturing_Director                     0.038909 -0.078170    0.008643
# Healthcare_Representative                 -0.053013 -0.040869   -0.000194
# Sales_Representative                       0.033147 -0.058139   -0.030626
# Research_Director                         -0.063688 -0.076004   -0.022547
# Manager                                   -0.011575 -0.053234    0.081937
# Job_Human_Resources                       -0.021642 -0.006807   -0.026335
# Marital_single                            -0.011087 -0.047919    0.005797
# Marital_married                            0.017401 -0.018329    0.042993
# Marital_divorced                          -0.008040  0.080644   -0.060061
#
#                             JobInvolvement  JobLevel  JobSatisfaction  \
# Age                               0.080115  0.483866         0.025750
# DailyRate                         0.019497  0.031256         0.033096
# DistanceFromHome                  0.049513  0.042324         0.000255
# Education                         0.078870  0.088204        -0.024897
# EnvironmentSatisfaction           0.037000 -0.041739         0.044807
# Gender                            0.029027 -0.102047         0.070678
# HourlyRate                        0.053182  0.003288        -0.079241
# JobInvolvement                    1.000000  0.015345        -0.010756
# JobLevel                          0.015345  1.000000         0.040498
# JobSatisfaction                  -0.010756  0.040498         1.000000
# MonthlyIncome                     0.002931  0.945951         0.036499
# MonthlyRate                      -0.016233  0.095663         0.020324
# NumCompaniesWorked               -0.039149  0.135675        -0.057775
# OverTime                         -0.020511 -0.025980         0.038806
# PercentSalaryHike                -0.014886 -0.029591        -0.033331
# PerformanceRating                -0.026386 -0.027826        -0.045454
# RelationshipSatisfaction          0.062317  0.013866        -0.002030
# StockOptionLevel                  0.060166  0.077114         0.086548
# TotalWorkingYears                 0.003514  0.745180         0.028717
# TrainingTimesLastYear            -0.048051 -0.062314         0.012714
# WorkLifeBalance                   0.003060  0.003179        -0.012339
# YearsAtCompany                   -0.010778  0.545367         0.090659
# YearsInCurrentRole               -0.019374  0.434570         0.070110
# YearsSinceLastPromotion           0.026008  0.341494         0.046174
# YearsWithCurrManager              0.023278  0.410357         0.013447
# Attrition                        -0.166818 -0.202023        -0.137183
# pdEmpb_Travel_Rarely             -0.068770  0.066258        -0.031997
# pdEmpb_Travel_Frequently          0.053034 -0.089150         0.048319
# pdEmpb_Non-Travel                 0.034621  0.024063        -0.019568
# Life_Sciences                     0.019246 -0.014236         0.019144
# Medical                           0.001718 -0.036409        -0.013870
# Marketing                         0.022189  0.138764        -0.032981
# Technical_Degree                 -0.019359 -0.075123         0.029866
# Education_Human_Resources        -0.035515 -0.066774        -0.083451
# Education_Other                  -0.033792  0.027696         0.039769
# pdEmp_Sales                      -0.033546  0.188556        -0.041323
# pdEmp_R&D                         0.038183 -0.149096         0.050435
# pdEmp_Dept_Human_Resources       -0.013966 -0.092523        -0.026075
# Research_Scientist               -0.011918 -0.334719         0.066818
# Laboratory_Technician             0.011891 -0.344716        -0.041286
# Sales_Executive                   0.018749  0.294200        -0.045767
# Manufacturing_Director           -0.000962  0.168238         0.004220
# Healthcare_Representative         0.005466  0.188936         0.015612
# Sales_Representative             -0.064685 -0.249457         0.000789
# Research_Director                 0.055530  0.369083        -0.003601
# Manager                           0.016968  0.483943         0.054772
# Job_Human_Resources              -0.013966 -0.092523        -0.026075
# Marital_single                   -0.075949 -0.127800        -0.067459
# Marital_married                   0.068312  0.113634         0.017227
# Marital_divorced                  0.007700  0.014580         0.060442
#
#                                   ...         Sales_Executive  \
# Age                               ...                0.120272
# DailyRate                         ...               -0.004078
# DistanceFromHome                  ...                0.125783
# Education                         ...                0.045339
# EnvironmentSatisfaction           ...                0.029094
# Gender                            ...                0.006253
# HourlyRate                        ...               -0.029350
# JobInvolvement                    ...                0.018749
# JobLevel                          ...                0.294200
# JobSatisfaction                   ...               -0.045767
# MonthlyIncome                     ...                0.216089
# MonthlyRate                       ...                0.066170
# NumCompaniesWorked                ...                0.093310
# OverTime                          ...                0.004933
# PercentSalaryHike                 ...               -0.079220
# PerformanceRating                 ...               -0.116510
# RelationshipSatisfaction          ...                0.071357
# StockOptionLevel                  ...                0.021279
# TotalWorkingYears                 ...                0.083554
# TrainingTimesLastYear             ...                0.004081
# WorkLifeBalance                   ...                0.040010
# YearsAtCompany                    ...                0.065550
# YearsInCurrentRole                ...                0.101985
# YearsSinceLastPromotion           ...                0.125022
# YearsWithCurrManager              ...                0.076162
# Attrition                         ...                0.030179
# pdEmpb_Travel_Rarely              ...                0.029539
# pdEmpb_Travel_Frequently          ...               -0.043260
# pdEmpb_Non-Travel                 ...                0.016033
# Life_Sciences                     ...               -0.119072
# Medical                           ...               -0.162650
# Marketing                         ...                0.435306
# Technical_Degree                  ...               -0.039174
# Education_Human_Resources         ...               -0.066506
# Education_Other                   ...                0.001678
# pdEmp_Sales                       ...                0.750339
# pdEmp_R&D                         ...               -0.694239
# pdEmp_Dept_Human_Resources        ...               -0.104770
# Research_Scientist                ...               -0.268380
# Laboratory_Technician             ...               -0.295082
# Sales_Executive                   ...                1.000000
# Manufacturing_Director            ...               -0.155735
# Healthcare_Representative         ...               -0.146162
# Sales_Representative              ...               -0.182342
# Research_Director                 ...               -0.098200
# Manager                           ...               -0.104770
# Job_Human_Resources               ...               -0.104770
# Marital_single                    ...                0.002233
# Marital_married                   ...                0.014568
# Marital_divorced                  ...               -0.020676
#
#                             Manufacturing_Director  Healthcare_Representative  \
# Age                                       0.077309                   0.124623
# DailyRate                                 0.034848                   0.010512
# DistanceFromHome                         -0.027956                   0.094924
# Education                                 0.076366                  -0.056592
# EnvironmentSatisfaction                   0.038909                  -0.053013
# Gender                                   -0.078170                  -0.040869
# HourlyRate                                0.008643                  -0.000194
# JobInvolvement                           -0.000962                   0.005466
# JobLevel                                  0.168238                   0.188936
# JobSatisfaction                           0.004220                   0.015612
# MonthlyIncome                             0.118154                   0.160006
# MonthlyRate                               0.043468                   0.010137
# NumCompaniesWorked                        0.007955                   0.016327
# OverTime                                 -0.024457                  -0.049620
# PercentSalaryHike                        -0.020865                   0.031035
# PerformanceRating                         0.003279                  -0.004521
# RelationshipSatisfaction                 -0.007817                  -0.079782
# StockOptionLevel                          0.064524                   0.026355
# TotalWorkingYears                         0.138070                   0.194867
# TrainingTimesLastYear                     0.027359                  -0.097777
# WorkLifeBalance                           0.039015                  -0.096932
# YearsAtCompany                            0.046652                   0.157419
# YearsInCurrentRole                        0.046335                   0.124153
# YearsSinceLastPromotion                   0.049794                   0.101609
# YearsWithCurrManager                      0.080718                   0.105058
# Attrition                                -0.127418                  -0.117718
# pdEmpb_Travel_Rarely                      0.055688                  -0.036443
# pdEmpb_Travel_Frequently                 -0.060804                   0.034257
# pdEmpb_Non-Travel                        -0.001088                   0.009062
# Life_Sciences                             0.098869                  -0.003962
# Medical                                   0.057303                   0.081070
# Marketing                                -0.115307                  -0.108220
# Technical_Degree                         -0.046600                  -0.010279
# Education_Human_Resources                -0.035100                  -0.032942
# Education_Other                          -0.069066                   0.045966
# pdEmp_Sales                              -0.207552                  -0.194795
# pdEmp_R&D                                 0.224325                   0.210536
# pdEmp_Dept_Human_Resources               -0.055294                  -0.051896
# Research_Scientist                       -0.141642                  -0.132936
# Laboratory_Technician                    -0.155735                  -0.146162
# Sales_Executive                          -0.155735                  -0.146162
# Manufacturing_Director                    1.000000                  -0.077140
# Healthcare_Representative                -0.077140                   1.000000
# Sales_Representative                     -0.096234                  -0.090319
# Research_Director                        -0.051827                  -0.048641
# Manager                                  -0.055294                  -0.051896
# Job_Human_Resources                      -0.055294                  -0.051896
# Marital_single                           -0.059053                  -0.088185
# Marital_married                           0.077563                   0.042528
# Marital_divorced                         -0.024174                   0.054328
#
#                             Sales_Representative  Research_Director   Manager  \
# Age                                    -0.225327           0.145412  0.217081
# DailyRate                              -0.009214          -0.044460  0.037486
# DistanceFromHome                       -0.101333          -0.018129 -0.081214
# Education                              -0.067147           0.059065  0.047329
# EnvironmentSatisfaction                 0.033147          -0.063688 -0.011575
# Gender                                 -0.058139          -0.076004 -0.053234
# HourlyRate                             -0.030626          -0.022547  0.081937
# JobInvolvement                         -0.064685           0.055530  0.016968
# JobLevel                               -0.249457           0.369083  0.483943
# JobSatisfaction                         0.000789          -0.003601  0.054772
# MonthlyIncome                          -0.246064           0.450641  0.555327
# MonthlyRate                            -0.001313           0.014391  0.082152
# NumCompaniesWorked                     -0.150758           0.077410  0.022330
# OverTime                                0.009385          -0.025659  0.026595
# PercentSalaryHike                       0.011128           0.048387 -0.006660
# PerformanceRating                      -0.034078           0.018404  0.038090
# RelationshipSatisfaction                0.045495          -0.028473  0.031682
# StockOptionLevel                       -0.086874           0.021709 -0.038471
# TotalWorkingYears                      -0.245096           0.272654  0.350942
# TrainingTimesLastYear                   0.041255           0.056190 -0.059146
# WorkLifeBalance                         0.105407          -0.025510  0.030922
# YearsAtCompany                         -0.194785           0.201243  0.248172
# YearsInCurrentRole                     -0.178588           0.159287  0.164823
# YearsSinceLastPromotion                -0.114529           0.063310  0.117556
# YearsWithCurrManager                   -0.201810           0.122535  0.186994
# Attrition                               0.125877          -0.132569 -0.079417
# pdEmpb_Travel_Rarely                   -0.045464           0.017777  0.032024
# pdEmpb_Travel_Frequently                0.117763          -0.040735 -0.050673
# pdEmpb_Non-Travel                      -0.101906           0.031831  0.023077
# Life_Sciences                          -0.097246           0.092933 -0.092833
# Medical                                -0.048132          -0.056385  0.060501
# Marketing                               0.188192          -0.072708  0.086284
# Technical_Degree                        0.044091           0.016389 -0.066232
# Education_Human_Resources              -0.041097          -0.022132 -0.023613
# Education_Other                        -0.019439           0.009380  0.053192
# pdEmp_Sales                             0.463663          -0.130874  0.027563
# pdEmp_R&D                              -0.428996           0.141450 -0.012724
# pdEmp_Dept_Human_Resources             -0.064741          -0.034866 -0.037199
# Research_Scientist                     -0.165842          -0.089314 -0.095290
# Laboratory_Technician                  -0.182342          -0.098200 -0.104770
# Sales_Executive                        -0.182342          -0.098200 -0.104770
# Manufacturing_Director                 -0.096234          -0.051827 -0.055294
# Healthcare_Representative              -0.090319          -0.048641 -0.051896
# Sales_Representative                    1.000000          -0.060681 -0.064741
# Research_Director                      -0.060681           1.000000 -0.034866
# Manager                                -0.064741          -0.034866  1.000000
# Job_Human_Resources                    -0.064741          -0.034866 -0.037199
# Marital_single                          0.142424          -0.066239 -0.056630
# Marital_married                        -0.074385           0.016371  0.087915
# Marital_divorced                       -0.080712           0.060020 -0.039881
#
#                             Job_Human_Resources  Marital_single  \
# Age                                   -0.086986       -0.193847
# DailyRate                              0.018962       -0.068893
# DistanceFromHome                       0.022063       -0.048887
# Education                              0.013712       -0.015415
# EnvironmentSatisfaction               -0.021642       -0.011087
# Gender                                -0.006807       -0.047919
# HourlyRate                            -0.026335        0.005797
# JobInvolvement                        -0.013966       -0.075949
# JobLevel                              -0.092523       -0.127800
# JobSatisfaction                       -0.026075       -0.067459
# MonthlyIncome                         -0.086962       -0.128845
# MonthlyRate                           -0.083668        0.050457
# NumCompaniesWorked                     0.018025       -0.059377
# OverTime                               0.003465        0.043219
# PercentSalaryHike                     -0.060370        0.053150
# PerformanceRating                     -0.023425        0.081664
# RelationshipSatisfaction               0.072600       -0.007069
# StockOptionLevel                       0.055318       -0.642399
# TotalWorkingYears                     -0.083661       -0.129731
# TrainingTimesLastYear                 -0.104032        0.001547
# WorkLifeBalance                        0.061521       -0.035978
# YearsAtCompany                        -0.064840       -0.097199
# YearsInCurrentRole                    -0.084873       -0.094820
# YearsSinceLastPromotion               -0.071799       -0.021723
# YearsWithCurrManager                  -0.102704       -0.084282
# Attrition                              0.079417        0.265456
# pdEmpb_Travel_Rarely                  -0.041424       -0.057375
# pdEmpb_Travel_Frequently               0.057521        0.085233
# pdEmpb_Non-Travel                     -0.017738       -0.032962
# Life_Sciences                         -0.092833        0.008688
# Medical                               -0.015972       -0.026548
# Marketing                             -0.077573        0.013525
# Technical_Degree                       0.007636        0.030007
# Education_Human_Resources              0.634781       -0.095369
# Education_Other                        0.003364        0.022580
# pdEmp_Sales                           -0.139630        0.095693
# pdEmp_R&D                             -0.246493       -0.045060
# pdEmp_Dept_Human_Resources             1.000000       -0.126836
# Research_Scientist                    -0.095290        0.086347
# Laboratory_Technician                 -0.104770        0.012608
# Sales_Executive                       -0.104770        0.002233
# Manufacturing_Director                -0.055294       -0.059053
# Healthcare_Representative             -0.051896       -0.088185
# Sales_Representative                  -0.064741        0.142424
# Research_Director                     -0.034866       -0.066239
# Manager                               -0.037199       -0.056630
# Job_Human_Resources                    1.000000       -0.126836
# Marital_single                        -0.126836        1.000000
# Marital_married                        0.041971       -0.665511
# Marital_divorced                       0.101824       -0.389994
#
#                             Marital_married  Marital_divorced
# Age                                0.121754          0.084548
# DailyRate                          0.052726          0.018384
# DistanceFromHome                   0.026540          0.026462
# Education                          0.004896          0.012629
# EnvironmentSatisfaction            0.017401         -0.008040
# Gender                            -0.018329          0.080644
# HourlyRate                         0.042993         -0.060061
# JobInvolvement                     0.068312          0.007700
# JobLevel                           0.113634          0.014580
# JobSatisfaction                    0.017227          0.060442
# MonthlyIncome                      0.114751          0.014467
# MonthlyRate                       -0.062434          0.015920
# NumCompaniesWorked                 0.007679          0.062433
# OverTime                          -0.013854         -0.035248
# PercentSalaryHike                 -0.014368         -0.046640
# PerformanceRating                 -0.063574         -0.020467
# RelationshipSatisfaction          -0.004892          0.014596
# StockOptionLevel                   0.253946          0.464674
# TotalWorkingYears                  0.105121          0.027421
# TrainingTimesLastYear              0.030078         -0.038982
# WorkLifeBalance                    0.069541         -0.042221
# YearsAtCompany                     0.122020         -0.032824
# YearsInCurrentRole                 0.097098         -0.004960
# YearsSinceLastPromotion            0.077550         -0.069366
# YearsWithCurrManager               0.087862         -0.006326
# Attrition                         -0.136697         -0.152833
# pdEmpb_Travel_Rarely               0.087087         -0.037956
# pdEmpb_Travel_Frequently          -0.077092         -0.008111
# pdEmpb_Non-Travel                 -0.028855          0.075517
# Life_Sciences                     -0.032099          0.029079
# Medical                            0.024663          0.001724
# Marketing                         -0.010465         -0.003468
# Technical_Degree                   0.026464         -0.068988
# Education_Human_Resources          0.001644          0.113467
# Education_Other                    0.000554         -0.028029
# pdEmp_Sales                       -0.033962         -0.073989
# pdEmp_R&D                          0.017158          0.033402
# pdEmp_Dept_Human_Resources         0.041971          0.101824
# Research_Scientist                -0.088642          0.004788
# Laboratory_Technician             -0.015986          0.004453
# Sales_Executive                    0.014568         -0.020676
# Marital_married                   0.028616  0.113314         0.010361
# Marital_divorced                  0.035189  0.027209         0.029692
#
#                                   ...         Sales_Executive  \
# Age                               ...                0.094993
# DailyRate                         ...               -0.004533
# DistanceFromHome                  ...                0.052692
# Education                         ...                0.073908
# EnvironmentSatisfaction           ...               -0.039799
# Gender                            ...                0.003011
# HourlyRate                        ...               -0.026012
# JobInvolvement                    ...               -0.005270
# JobLevel                          ...                0.242842
# JobSatisfaction                   ...                0.018117
# MonthlyIncome                     ...                0.166367
# MonthlyRate                       ...                0.006046
# NumCompaniesWorked                ...                0.056565
# OverTime                          ...               -0.016785
# PercentSalaryHike                 ...               -0.043132
# PerformanceRating                 ...               -0.053559
# RelationshipSatisfaction          ...                0.007949
# StockOptionLevel                  ...                0.033482
# TotalWorkingYears                 ...                0.073952
# TrainingTimesLastYear             ...                0.028626
# WorkLifeBalance                   ...               -0.019730
# YearsAtCompany                    ...                0.095746
# YearsInCurrentRole                ...                0.148300
# YearsSinceLastPromotion           ...                0.114548
# YearsWithCurrManager              ...                0.129172
# Attrition                         ...                0.018426
# pdEmpb_Travel_Rarely              ...                0.006489
# pdEmpb_Travel_Frequently          ...               -0.018597
# pdEmpb_Non-Travel                 ...                0.018317
# Life_Sciences                     ...               -0.048245
# Medical                           ...               -0.147567
# Marketing                         ...                0.414827
# Technical_Degree                  ...               -0.074922
# Education_Human_Resources         ...               -0.071959
# Education_Other                   ...               -0.042145
# pdEmp_Sales                       ...                0.770222
# pdEmp_R&D                         ...               -0.705717
# pdEmp_Dept_Human_Resources        ...               -0.109887
# Research_Scientist                ...               -0.276501
# Laboratory_Technician             ...               -0.278885
# Sales_Executive                   ...                1.000000
# Manufacturing_Director            ...               -0.158283
# Healthcare_Representative         ...               -0.146051
# Sales_Representative              ...               -0.166086
# Research_Director                 ...               -0.108714
# Manager                           ...               -0.121630
# Job_Human_Resources               ...               -0.103297
# Marital_single                    ...               -0.009669
# Marital_married                   ...                0.025360
# Marital_divorced                  ...               -0.019909
#
#                             Manufacturing_Director  Healthcare_Representative  \
# Age                                       0.072323                   0.101797
# DailyRate                                -0.002077                   0.040269
# DistanceFromHome                         -0.018775                   0.060395
# Education                                 0.033553                  -0.015124
# EnvironmentSatisfaction                   0.056540                  -0.013879
# Gender                                   -0.036501                  -0.004599
# HourlyRate                               -0.009945                   0.039956
# JobInvolvement                            0.031598                   0.018999
# JobLevel                                  0.146587                   0.167718
# JobSatisfaction                          -0.015071                   0.025053
# MonthlyIncome                             0.083923                   0.117432
# MonthlyRate                              -0.026915                  -0.004934
# NumCompaniesWorked                       -0.006954                   0.025476
# OverTime                                 -0.053682                  -0.053674
# PercentSalaryHike                         0.006539                  -0.004100
# PerformanceRating                        -0.004921                  -0.014897
# RelationshipSatisfaction                 -0.037214                  -0.024568
# StockOptionLevel                          0.040472                   0.022882
# TotalWorkingYears                         0.094873                   0.156484
# TrainingTimesLastYear                     0.002963                  -0.023721
# WorkLifeBalance                           0.007825                  -0.019062
# Medical                                -0.069081           0.025884  0.019158
# Marketing                               0.181006          -0.073042  0.036291
# Technical_Degree                        0.044854           0.019649 -0.046497
# Education_Human_Resources              -0.040961          -0.026811  0.056740
# Education_Other                        -0.027405          -0.005108 -0.005342
# pdEmp_Sales                             0.438430          -0.141147  0.015165
# pdEmp_R&D                              -0.401712           0.154048 -0.039356
# pdEmp_Dept_Human_Resources             -0.062551          -0.040943  0.060742
# Research_Scientist                     -0.157392          -0.103023 -0.115263
# Laboratory_Technician                  -0.158749          -0.103911 -0.116257
# Sales_Executive                        -0.166086          -0.108714 -0.121630
# Manufacturing_Director                 -0.090099          -0.058975 -0.065982
# Healthcare_Representative              -0.083136          -0.054418 -0.060883
# Sales_Representative                    1.000000          -0.061883 -0.069235
# Research_Director                      -0.061883           1.000000 -0.045319
# Manager                                -0.069235          -0.045319  1.000000
# Job_Human_Resources                    -0.058799          -0.038488 -0.043061
# Marital_single                          0.098431          -0.046027 -0.084306
# Marital_married                        -0.064783           0.024754  0.081316
# Marital_divorced                       -0.041200           0.026250  0.002713
#
#                             Job_Human_Resources  Marital_single  \
# Age                                   -0.042209       -0.192753
# DailyRate                             -0.005697       -0.107238
# DistanceFromHome                       0.022423       -0.027595
# Education                             -0.012731       -0.035418
# EnvironmentSatisfaction               -0.001459        0.017936
# Gender                                -0.004621       -0.029944
# HourlyRate                            -0.007029       -0.012902
# JobInvolvement                        -0.007818       -0.057086
# JobLevel                              -0.075597       -0.136245
# JobSatisfaction                       -0.035386       -0.034246
# MonthlyIncome                         -0.070034       -0.138054
# MonthlyRate                           -0.061363        0.035060
# NumCompaniesWorked                     0.016304       -0.076973
# OverTime                              -0.030425        0.021840
# PercentSalaryHike                     -0.054685        0.024706
# PerformanceRating                     -0.034771        0.047512
# RelationshipSatisfaction               0.064900       -0.002949
# StockOptionLevel                       0.015374       -0.644946
# TotalWorkingYears                     -0.054533       -0.163562
# TrainingTimesLastYear                 -0.063637        0.026256
# WorkLifeBalance                        0.050624       -0.038550
# YearsAtCompany                        -0.029001       -0.100430
# YearsInCurrentRole                    -0.051966       -0.101086
# YearsSinceLastPromotion               -0.055376       -0.067905
# YearsWithCurrManager                  -0.051232       -0.064308
# Attrition                              0.015387        0.223347
# pdEmpb_Travel_Rarely                   0.012245       -0.048879
# pdEmpb_Travel_Frequently              -0.000019        0.051699
# pdEmpb_Non-Travel                     -0.021325        0.002869
# Life_Sciences                         -0.087322        0.017408
# Medical                               -0.021790       -0.053880
# Marketing                             -0.069402        0.010939
# Technical_Degree                      -0.001236        0.069844
# Education_Human_Resources              0.595861       -0.094492
# Education_Other                       -0.011342        0.017327
# pdEmp_Sales                           -0.134113        0.039804
# pdEmp_R&D                             -0.249844        0.001672
# pdEmp_Dept_Human_Resources             0.940027       -0.099918
# Research_Scientist                    -0.097889        0.081497
# Laboratory_Technician                 -0.098733        0.042900
# Sales_Executive                       -0.103297       -0.009669
# Manufacturing_Director                -0.056037       -0.051148
# Healthcare_Representative             -0.051706       -0.059363
# Sales_Representative                  -0.058799        0.098431
# Research_Director                     -0.038488       -0.046027
# Manager                               -0.043061       -0.084306
# Job_Human_Resources                    1.000000       -0.099849
# Marital_single                        -0.099849        1.000000
# Marital_married                        0.065015       -0.682521
# Marital_divorced                       0.042678       -0.387841
#
#                             Marital_married  Marital_divorced
# Age                                0.121769          0.087103
# DailyRate                          0.072049          0.043034
# DistanceFromHome                   0.038676         -0.014322
# Education                          0.010778          0.030630
# EnvironmentSatisfaction           -0.000895         -0.021266
# Gender                            -0.011782          0.052248
# HourlyRate                         0.034322         -0.027176
# JobInvolvement                     0.028616          0.035189
# JobLevel                           0.113314          0.027209
# JobSatisfaction                    0.010361          0.029692
# MonthlyIncome                      0.115031          0.027302
# MonthlyRate                       -0.056155          0.027044
# NumCompaniesWorked                 0.007506          0.086643
# OverTime                          -0.020267         -0.001711
# PercentSalaryHike                 -0.012224         -0.015431
# PerformanceRating                 -0.051416          0.005519
# RelationshipSatisfaction          -0.028085          0.039102
# StockOptionLevel                   0.295326          0.432830
# TotalWorkingYears                  0.114190          0.060213
# TrainingTimesLastYear              0.003389         -0.037058
# WorkLifeBalance                    0.063443         -0.031878
# YearsAtCompany                     0.097575          0.002341
# YearsInCurrentRole                 0.094249          0.007355
# YearsSinceLastPromotion            0.084968         -0.022371
# YearsWithCurrManager               0.081035         -0.021902
# Attrition                         -0.120016         -0.127513
# pdEmpb_Travel_Rarely               0.094819         -0.058549
# pdEmpb_Travel_Frequently          -0.078698          0.034699
# pdEmpb_Non-Travel                 -0.039967          0.046822
# Life_Sciences                     -0.017428          0.000244
# Medical                            0.039045          0.018032
# Marketing                         -0.002838         -0.010080
# Technical_Degree                  -0.031605         -0.047349
# Education_Human_Resources          0.056552          0.046663
# Education_Other                   -0.029294          0.015309
# pdEmp_Sales                       -0.003906         -0.044773
# pdEmp_R&D                         -0.023426          0.027455
# pdEmp_Dept_Human_Resources         0.067277          0.039911
# Research_Scientist                -0.041076         -0.049955
# Laboratory_Technician             -0.068961          0.033405
# Sales_Executive                    0.025360         -0.019909
# Manufacturing_Director             0.034708          0.020092
# Healthcare_Representative          0.034887          0.030123
# Sales_Representative              -0.064783         -0.041200
# Research_Director                  0.024754          0.026250
# Manager                            0.081316          0.002713
# Job_Human_Resources                0.065015          0.042678
# Marital_single                    -0.682521         -0.387841
# Marital_married                    1.000000         -0.408948
# Marital_divorced                  -0.408948          1.000000
#
# [50 rows x 50 columns]

# %%
pdEmp.corr()
# Out:
#                                  Age  DailyRate  DistanceFromHome  Education  \
# Age                         1.000000   0.010661         -0.001686   0.208034
# DailyRate                   0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome           -0.001686  -0.004985          1.000000   0.021042
# Education                   0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction     0.010146   0.018355         -0.016075  -0.027128
# Gender                     -0.036311  -0.011716         -0.001851  -0.016547
# HourlyRate                  0.024287   0.023381          0.031131   0.016775
# JobInvolvement              0.029820   0.046135          0.008783   0.042438
# JobLevel                    0.509604   0.002966          0.005303   0.101589
# JobSatisfaction            -0.004892   0.030571         -0.003669  -0.011296
# MonthlyInc
# TotalWorkingYears                         -0.002693 -0.046881   -0.002334
# TrainingTimesLastYear                     -0.019359 -0.038787   -0.008548
# WorkLifeBalance                            0.027627 -0.002753   -0.004607
# YearsAtCompany                             0.001458 -0.029747   -0.019582
# YearsInCurrentRole                         0.018007 -0.041483   -0.024106
# YearsSinceLastPromotion                    0.016194 -0.026985   -0.026716
# YearsWithCurrManager                      -0.004999 -0.030599   -0.020123
# Attrition                                 -0.103369  0.029453   -0.006846
# pdEmpb_Travel_Rarely                       0.008496 -0.014682    0.027541
# pdEmpb_Travel_Frequently                  -0.012624 -0.022015   -0.018819
# pdEmpb_Non-Travel                          0.003568  0.050461   -0.016994
# Life_Sciences                             -0.024526  0.006770    0.038759
# Medical                                   -0.021299 -0.013146   -0.020418
# Marketing                                  0.000479 -0.024143    0.004452
# Technical_Degree                           0.027713  0.003886    0.011283
# Education_Human_Resources                 -0.006898  0.028956   -0.033670
# Education_Other                            0.064602  0.022992   -0.042163
# pdEmp_Sales                               -0.025606 -0.032017   -0.012047
# pdEmp_R&D                                  0.027976  0.015760    0.018686
# pdEmp_Dept_Human_Resources                -0.007597  0.035652   -0.016551
# Research_Scientist                         0.001940  0.009745    0.020034
# Laboratory_Technician                     -0.001533  0.067793    0.018028
# Sales_Executive                           -0.024421 -0.005348   -0.011886
# Manufacturing_Director                     0.059178 -0.065197   -0.014394
# Healthcare_Representative                  0.014090  0.006823    0.014599
# Sales_Representative                       0.002949 -0.028877   -0.018703
# Research_Director                         -0.048689 -0.006121   -0.025128
# Manager                                    0.010730 -0.033880    0.012659
# Job_Human_Resources                       -0.022014  0.036082   -0.016189
# Marital_single                             0.009035 -0.032752   -0.033436
# Marital_married                           -0.022180 -0.007804    0.036432
# Marital_divorced                           0.016439  0.046076   -0.006150
#
#                             JobInvolvement  JobLevel  JobSatisfaction  \
# Age                               0.029820  0.509604        -0.004892
# DailyRate                         0.046135  0.002966         0.030571
# DistanceFromHome                  0.008783  0.005303        -0.003669
# Education                         0.042438  0.101589        -0.011296
# EnvironmentSatisfaction          -0.008278  0.001212        -0.006784
# Gender                            0.017960 -0.039403         0.033252
# HourlyRate                        0.042861 -0.027853        -0.071335
# JobInvolvement                    1.000000 -0.012630        -0.021476
# JobLevel                         -0.012630  1.000000        -0.001944
# JobSatisfaction                  -0.021476 -0.001944         1.000000
# MonthlyIncome                    -0.015271  0.950300        -0.007157
# MonthlyRate                      -0.016322  0.039563         0.000644
# NumCompaniesWorked                0.015012  0.142501        -0.055699
# OverTime                         -0.003507  0.000544         0.024539
# PercentSalaryHike                -0.017205 -0.034730         0.020002
# PerformanceRating                -0.029071 -0.021222         0.002297
# RelationshipSatisfaction          0.034297  0.021642        -0.012454
# StockOptionLevel                  0.021523  0.013984         0.010690
# TotalWorkingYears                -0.005533  0.782208        -0.020185
# TrainingTimesLastYear            -0.015338 -0.018191        -0.005779
# WorkLifeBalance                  -0.014617  0.037818        -0.019459
# YearsAtCompany                   -0.021355  0.534739        -0.003803
# YearsInCurrentRole                0.008717  0.389447        -0.002305
# YearsSinceLastPromotion          -0.024184  0.353885        -0.018214
# YearsWithCurrManager              0.025976  0.375281        -0.027656
# Attrition                        -0.130016 -0.169105        -0.103481
# pdEmpb_Travel_Rarely              0.026714  0.023433        -0.036562
# pdEmpb_Travel_Frequently          0.004424 -0.021557         0.027117
# pdEmpb_Non-Travel                -0.045779 -0.007295         0.019802
# Life_Sciences                     0.003228 -0.008431         0.052004
# Medical                           0.017103 -0.014114        -0.022645
# Marketing                        -0.018657  0.092698        -0.023528
# Technical_Degree                 -0.004519 -0.054707        -0.019795
# Education_Human_Resources         0.002079  0.010409        -0.021467
# Education_Other                  -0.011895 -0.016724         0.003380
# pdEmp_Sales                      -0.026107  0.114307         0.013499
# pdEmp_R&D                         0.023187 -0.107830        -0.002798
# pdEmp_Dept_Human_Resources        0.004789 -0.006157        -0.024068
# Research_Scientist                0.047604 -0.387788         0.020503
# Laboratory_Technician            -0.022724 -0.344608        -0.015710
# Sales_Executive                  -0.011413  0.127490         0.012604
# Manufacturing_Director           -0.021939  0.114896        -0.013747
# Healthcare_Representative         0.001272  0.115704         0.016367
# Sales_Representative             -0.027282 -0.216559         0.001413
# Research_Director                 0.015200  0.414319        -0.006217
# Manager                           0.017112  0.552744        -0.005620
# Job_Human_Resources              -0.004952 -0.100922        -0.029681
# Marital_single                   -0.045253 -0.087072         0.024571
# Marital_married                   0.028324  0.050547        -0.010315
# Marital_divorced                  0.016815  0.037087        -0.015197
#
#                                   ...         Sales_Executive  \
# Age                               ...               -0.002001
# DailyRate                         ...               -0.000513
# DistanceFromHome                  ...                0.030761
# Education                         ...                0.053398
# EnvironmentSatisfaction           ...               -0.024421
# Gender                            ...               -0.005348
# HourlyRate                        ...               -0.011886
# JobInvolvement                    ...               -0.011413
# JobLevel                          ...                0.127490
# JobSatisfaction                   ...                0.012604
# MonthlyIncome                     ...                0.047792
# MonthlyRate                       ...                0.011854
# NumCompaniesWorked                ...                0.005913
# OverTime                          ...                0.006341
# PercentSalaryHike                 ...               -0.046683
# PerformanceRating                 ...               -0.041401
# RelationshipSatisfaction          ...               -0.004836
# StockOptionLevel                  ...                0.015756
# TotalWorkingYears                 ...               -0.012241
# TrainingTimesLastYear             ...                0.013241
# WorkLifeBalance                   ...                0.032092
# YearsAtCompany                    ...                0.042602
# YearsInCurrentRole                ...                0.092349
# YearsSinceLastPromotion           ...                0.049202
# YearsWithCurrManager              ...                0.083028
# Attrition                         ...                0.019774
# pdEmpb_Travel_Rarely              ...               -0.011920
# pdEmpb_Travel_Frequently          ...               -0.010175
# pdEmpb_Non-Travel                 ...                0.031022
# Life_Sciences                     ...               -0.091122
# Medical                           ...               -0.133532
# Marketing                         ...                0.457308
# Technical_Degree                  ...               -0.058843
# Education_Human_Resources         ...               -0.073020
# Education_Other                   ...               -0.036995
# pdEmp_Sales                       ...                0.808869
# pdEmp_R&D                         ...               -0.733497
# pdEmp_Dept_Human_Resources        ...               -0.112959
# Research_Scientist                ...               -0.265775
# Laboratory_Technician             ...               -0.246873
# Sales_Executive                   ...                1.000000
# Manufacturing_Director            ...               -0.176592
# Healthcare_Representative         ...               -0.166971
# Sales_Representative              ...               -0.130586
# Research_Director                 ...               -0.128066
# Manager                           ...               -0.145765
# Job_Human_Resources               ...               -0.102226
# Marital_single                    ...                0.006210
# Marital_married                   ...                0.005751
# Marital_divorced                  ...               -0.013853
#
#                             Manufacturing_Director  Healthcare_Representative  \
# Age                                       0.049726                   0.098825
# DailyRate                                -0.005302                   0.040141
# DistanceFromHome                          0.011848                   0.022916
# Education                                -0.005290                   0.024270
# EnvironmentSatisfaction                   0.059178                   0.014090
# Gender                                   -0.065197                   0.006823
# HourlyRate                               -0.014394                   0.014599
# JobInvolvement                           -0.021939                   0.001272
# JobLevel                                  0.114896                   0.115704
# JobSatisfaction                          -0.013747                   0.016367
# MonthlyIncome                             0.055684                   0.068177
# MonthlyRate                               0.007711                   0.003829
# NumCompaniesWorked                        0.009580                   0.026955
# OverTime                                 -0.010302                  -0.000382
# PercentSalaryHike                         0.034682                   0.020591
# PerformanceRating                         0.029775                  -0.000928
# RelationshipSatisfaction                  0.003640                  -0.005090
# StockOptionLevel                          0.007735                   0.014021
# TotalWorkingYears                         0.064077                   0.112159
# TrainingTimesLastYear                    -0.013987                  -0.012432
# WorkLifeBalance                           0.002011                  -0.026101
# YearsAtCompany                            0.031968                   0.069758
# YearsInCurrentRole                        0.067877                   0.054695
# YearsSinceLastPromotion                  -0.007241                   0.075902
# YearsWithCurrManager                      0.076207                   0.039407
# Attrition                                -0.082994                  -0.078696
# pdEmpb_Travel_Rarely                      0.000598                  -0.015503
# pdEmpb_Travel_Frequently                  0.009783                   0.008029
# pdEmpb_Non-Travel                        -0.013536                   0.012878
# Life_Sciences                             0.052023                   0.029084
# Medical                                   0.035496                   0.034165
# Marketing                                -0.115206                  -0.108929
# Technical_Degree                          0.007817                   0.018681
# Education_Human_Resources                -0.045251                  -0.042785
# Education_Other                          -0.010820                   0.017609
# pdEmp_Sales                              -0.218320                  -0.206425
# pdEmp_R&D                                 0.240754                   0.227637
# pdEmp_Dept_Human_Resources               -0.070000                  -0.066186
# Research_Scientist                       -0.164700                  -0.155727
# Laboratory_Technician                    -0.152987                  -0.144652
# Sales_Executive                          -0.176592                  -0.166971
# Manufacturing_Director                    1.000000                  -0.103472
# Healthcare_Representative                -0.103472                   1.000000
# Sales_Representative                     -0.080924                  -0.076515
# Research_Director                        -0.079362                  -0.075038
# Manager                                  -0.090330                  -0.085409
# Job_Human_Resources                      -0.063349                  -0.059898
# Marital_single                           -0.021331                  -0.030126
# Marital_married                           0.002819                   0.004913
# Marital_divorced                          0.020543                   0.027897
#
#                             Sales_Representative  Research_Director   Manager  \
# Age                                    -0.175785           0.185891  0.294248
# DailyRate                               0.005375          -0.000021 -0.013224
# DistanceFromHome                       -0.015994          -0.022351 -0.039190
# Education                              -0.091465           0.049694  0.028453
# EnvironmentSatisfaction                 0.002949          -0.048689  0.010730
# Gender                                 -0.028877          -0.006121 -0.033880
# HourlyRate                             -0.018703          -0.025128  0.012659
# JobInvolvement                         -0.027282           0.015200  0.017112
# JobLevel                               -0.216559           0.414319  0.552744
# JobSatisfaction                         0.001413          -0.006217 -0.005620
# MonthlyIncome                          -0.201514           0.485818  0.619573
# MonthlyRate                            -0.001200           0.025875  0.031717
# NumCompaniesWorked                     -0.104494           0.097925  0.042125
# OverTime                                0.003347           0.002400 -0.011086
# PercentSalaryHike                       0.031102          -0.017017 -0.005394
# PerformanceRating                      -0.006214          -0.035744  0.032050
# RelationshipSatisfaction               -0.024859          -0.005492  0.025638
# StockOptionLevel                       -0.048067           0.015807 -0.015637
# TotalWorkingYears                      -0.207726           0.312148  0.465837
# TrainingTimesLastYear                   0.040377          -0.004527  0.003052
# WorkLifeBalance                         0.045148           0.034403  0.005137
# YearsAtCompany                         -0.163464           0.153918  0.330965
# YearsInCurrentRole                     -0.149751           0.136332  0.167499
# YearsSinceLastPromotion                -0.085622           0.074455  0.224255
# YearsWithCurrManager                   -0.168743           0.131279  0.164695
# Attrition                               0.157234          -0.088870 -0.083316
# pdEmpb_Travel_Rarely                   -0.025257           0.034600  0.027294
# pdEmpb_Travel_Frequently                0.055469          -0.023579 -0.042583
# pdEmpb_Non-Travel                      -0.033780          -0.021431  0.014078
# Life_Sciences                          -0.043208           0.018401 -0.011143
# Medical                                -0.051990           0.062898 -0.001128
# Marketing                               0.133065          -0.083548  0.025577
# Technical_Degree                        0.057185          -0.022905 -0.038946
# Education_Human_Resources              -0.033462          -0.032816  0.082271
# Education_Other                        -0.033774          -0.006044 -0.008046
# pdEmp_Sales                             0.370667          -0.158327  0.035248
# pdEmp_R&D                              -0.336127           0.174596 -0.071356
# pdEmp_Dept_Human_Resources             -0.051764          -0.050765  0.087615
# Research_Scientist                     -0.121792          -0.119442 -0.135949
# Laboratory_Technician                  -0.113130          -0.110947 -0.126280
# Sales_Executive                        -0.130586          -0.128066 -0.145765
# Manufacturing_Director                 -0.080924          -0.079362 -0.090330
# Healthcare_Representative              -0.076515          -0.075038 -0.085409
# Sales_Representative                    1.000000          -0.058687 -0.066797
# Research_Director                      -0.058687           1.000000 -0.065508
# Manager                                -0.066797          -0.065508  1.000000
# Job_Human_Resources                    -0.046845          -0.045941 -0.052290
# Marital_single                          0.072439          -0.042299 -0.055176
# Marital_married                        -0.023659           0.008271  0.049982
# Marital_divorced                       -0.052890           0.037524  0.001997
#
#                             Job_Human_Resources  Marital_single  \
# Age                                   -0.029856       -0.119185
# DailyRate                             -0.021156       -0.075835
# DistanceFromHome                      -0.024089       -0.027445
# Education                             -0.005295        0.004168
# EnvironmentSatisfaction               -0.022014        0.009035
# Gender                                 0.036082       -0.032752
# HourlyRate                            -0.016189       -0.033436
# JobInvolvement                        -0.004952       -0.045253
# JobLevel                              -0.100922       -0.087072
# JobSatisfaction                       -0.029681        0.024571
# MonthlyIncome                         -0.092250       -0.089361
# MonthlyRate                           -0.027470        0.037260
# NumCompaniesWorked                     0.020578       -0.019161
# OverTime                              -0.014026       -0.006498
# PercentSalaryHike                     -0.021032       -0.001386
# PerformanceRating                     -0.010154       -0.001045
# RelationshipSatisfaction               0.044169        0.040817
# StockOptionLevel                      -0.009864       -0.638957
# TotalWorkingYears                     -0.076482       -0.089529
# TrainingTimesLastYear                 -0.035902        0.024129
# WorkLifeBalance                        0.043887        0.014921
# YearsAtCompany                        -0.052569       -0.070935
# YearsInCurrentRole                    -0.057876       -0.086486
# YearsSinceLastPromotion               -0.054603       -0.053090
# YearsWithCurrManager                  -0.051006       -0.047793
# Attrition                              0.036215        0.175419
# pdEmpb_Travel_Rarely                   0.008962       -0.020808
# pdEmpb_Travel_Frequently               0.001896        0.027734
# pdEmpb_Non-Travel                     -0.015890       -0.004622
# Life_Sciences                         -0.063119        0.021469
# Medical                               -0.042895       -0.004249
# Marketing                             -0.066690       -0.013323
# Technical_Degree                      -0.008623        0.014265
# Education_Human_Resources              0.549751       -0.072051
# Education_Other                        0.001594        0.004972
# pdEmp_Sales                           -0.126381        0.033002
# pdEmp_R&D                             -0.263128       -0.009990
# pdEmp_Dept_Human_Resources             0.904983       -0.051443
# Research_Scientist                    -0.095342        0.053522
# Laboratory_Technician                 -0.088561        0.019873
# Sales_Executive                       -0.102226        0.006210
# Manufacturing_Director                -0.063349       -0.021331
# Healthcare_Representative             -0.059898       -0.030126
# Sales_Representative                  -0.046845        0.072439
# Research_Director                     -0.045941       -0.042299
# Manager                               -0.052290       -0.055176
# Job_Human_Resources                    1.000000       -0.052320
# Marital_single                        -0.052320        1.000000
# Marital_married                        0.030995       -0.629981
# Marital_divorced                       0.021541       -0.366691
#
#                             Marital_married  Marital_divorced
# Age                                0.083919          0.033120
# DailyRate                          0.040035          0.037080
# DistanceFromHome                   0.030232         -0.005440
# Education                         -0.001865         -0.002439
# EnvironmentSatisfaction           -0.022180          0.016439
# Gender                            -0.007804          0.046076
# HourlyRate                         0.036432         -0.006150
# JobInvolvement                     0.028324          0.016815
# JobLevel                           0.050547          0.037087
# JobSatisfaction                   -0.010315         -0.015197
# MonthlyIncome                      0.056767          0.032203
# MonthlyRate                       -0.034689         -0.000227
# NumCompaniesWorked                -0.016142          0.040824
# OverTime                          -0.013502          0.023462
# PercentSalaryHike                  0.020895         -0.023478
# PerformanceRating                  0.009585         -0.010310
# RelationshipSatisfaction          -0.043382          0.006199
# StockOptionLevel                   0.225574          0.446285
# TotalWorkingYears                  0.053512          0.036291
# TrainingTimesLastYear             -0.029602          0.008405
# WorkLifeBalance                   -0.006388         -0.009080
# YearsAtCompany                     0.044925          0.025728
# YearsInCurrentRole                 0.065488          0.018532
# YearsSinceLastPromotion            0.054102         -0.005279
# YearsWithCurrManager               0.032972          0.014095
# Attrition                         -0.090984         -0.087716
# pdEmpb_Travel_Rarely               0.055613         -0.043287
# pdEmpb_Travel_Frequently          -0.030785          0.005779
# pdEmpb_Non-Travel                 -0.043635          0.057455
# Life_Sciences                     -0.017866         -0.002672
# Medical                           -0.007139          0.013316
# Marketing                          0.018491         -0.007212
# Technical_Degree                   0.002710         -0.019243
# Education_Human_Resources          0.057339          0.012107
# Education_Other                   -0.009171          0.005411
# pdEmp_Sales                        0.005378         -0.043451
# pdEmp_R&D                         -0.019997          0.035158
# pdEmp_Dept_Human_Resources         0.034767          0.016037
# Research_Scientist                -0.039987         -0.012115
# Laboratory_Technician             -0.009233         -0.011224
# Sales_Executive                    0.005751         -0.013853
# Manufacturing_Director             0.002819          0.020543
# Healthcare_Representative          0.004913          0.027897
# Sales_Representative              -0.023659         -0.052890
# Research_Director                  0.008271          0.037524
# Manager                            0.049982          0.001997
# Job_Human_Resources                0.030995          0.021541
# Marital_single                    -0.629981         -0.366691
# Marital_married                    1.000000         -0.491506
# Marital_divorced                  -0.491506          1.000000
#
# [50 rows x 50 columns]

# %%
pdEmp.corr().loc['Attrition']
# though we have seen the correlation and
# Out:
# Age                          -0.159205
# DailyRate                    -0.056652
# DistanceFromHome              0.077924
# Education                    -0.031373
# EnvironmentSatisfaction      -0.103369
# Gender                        0.029453
# HourlyRate                   -0.006846
# JobInvolvement               -0.130016
# JobLevel                     -0.169105
# JobSatisfaction              -0.103481
# MonthlyIncome                -0.159840
# MonthlyRate                   0.015170
# NumCompaniesWorked            0.043494
# OverTime                      0.246118
# PercentSalaryHike            -0.013478
# PerformanceRating             0.002889
# RelationshipSatisfaction     -0.045872
# StockOptionLevel             -0.137145
# TotalWorkingYears            -0.171063
# TrainingTimesLastYear        -0.059478
# WorkLifeBalance              -0.063939
# YearsAtCompany               -0.134392
# YearsInCurrentRole           -0.160545
# YearsSinceLastPromotion      -0.033019
# YearsWithCurrManager         -0.156199
# Attrition                     1.000000
# pdEmpb_Travel_Rarely         -0.049538
# pdEmpb_Travel_Frequently      0.115143
# pdEmpb_Non-Travel            -0.074457
# Life_Sciences                -0.032703
# Medical                      -0.046999
# Marketing                     0.055781
# Technical_Degree              0.069355
# Education_Human_Resources     0.036466
# Education_Other              -0.017898
# pdEmp_Sales                   0.080855
# pdEmp_R&D                    -0.085293
# pdEmp_Dept_Human_Resources    0.016832
# Research_Scientist           -0.000360
# Laboratory_Technician         0.098290
# Sales_Executive               0.019774
# Manufacturing_Director       -0.082994
# Healthcare_Representative    -0.078696
# Sales_Representative          0.157234
# Research_Director            -0.088870
# Manager                      -0.083316
# Job_Human_Resources           0.036215
# Marital_single                0.175419
# Marital_married              -0.090984
# Marital_divorced             -0.087716
# Name: Attrition, dtype: float64

# %%
# As we can see there few variable which has the positive relation with target class.
# for now we will be working with all variables
# converting explored data in data frames.
emp_under = spark.createDataFrame(pdEmp_class_1_under_data)
emp_over = spark.createDataFrame(pdEmp_class_2_over_data)
emp_normal = spark.createDataFrame(pdEmp)

# %%
col_names = emp_normal.schema.names
col_names.remove("Attrition")
print(*col_names, sep = ", ")
# Out:
# Age, DailyRate, DistanceFromHome, Education, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobSatisfaction, MonthlyIncome, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, pdEmpb_Travel_Rarely, pdEmpb_Travel_Frequently, pdEmpb_Non-Travel, Life_Sciences, Medical, Marketing, Technical_Degree, Education_Human_Resources, Education_Other, pdEmp_Sales, pdEmp_R&D, pdEmp_Dept_Human_Resources, Research_Scientist, Laboratory_Technician, Sales_Executive, Manufacturing_Director, Healthcare_Representative, Sales_Representative, Research_Director, Manager, Job_Human_Resources, Marital_single, Marital_married, Marital_divorced

# %%
# Preparing data for machine learning. We need only two columns only - features and label
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import VectorAssembler
import matplotlib.pyplot as plt
import numpy as np

# %%
vassembler = VectorAssembler(inputCols=col_names, outputCol="features")
vassembler_emp_under = vassembler.transform(emp_under)
vassembler_emp_over = vassembler.transform(emp_over)
vassembler_emp_normal = vassembler.transform(emp_normal)

vassembler_emp_under = vassembler_emp_under.select(['features', 'Attrition'])
vassembler_emp_over = vassembler_emp_over.select(['features', 'Attrition'])
vassembler_emp_normal = vassembler_emp_normal.select(['features', 'Attrition'])
vassembler_emp_under.show(3)
vassembler_emp_over.show(3)
vassembler_emp_normal.show(3)
# Out:
# +--------------------+---------+
# |            features|Attrition|
# +--------------------+---------+
# |(49,[0,1,2,3,4,5,...|        0|
# |(49,[0,1,2,3,4,6,...|        0|
# |(49,[0,1,2,3,4,5,...|        0|
# +--------------------+---------+
# only showing top 3 rows
#
# +--------------------+---------+
# |            features|Attrition|
# +--------------------+---------+
# |(49,[0,1,2,3,4,5,...|        0|
# |(49,[0,1,2,3,4,6,...|        0|
# |(49,[0,1,2,3,4,5,...|        0|
# +--------------------+---------+
# only showing top 3 rows
#
# +--------------------+---------+
# |            features|Attrition|
# +--------------------+---------+
# |(49,[0,1,2,3,4,6,...|        1|
# |(49,[0,1,2,3,4,5,...|        0|
# |(49,[0,1,2,3,4,5,...|        1|
# +--------------------+---------+
# only showing top 3 rows

# %%
def linear_regression(data, splitfrac = [0.7,0.3]):
    train_data,test_data = data.randomSplit(splitfrac)
    # Let's see our training data.
    train_data.describe().show()

    # And our testing data.
    test_data.describe().show()

    lr = LinearRegression(featuresCol='features', labelCol='Attrition')
    
    # Fit the training data.
    lr_model = lr.fit(train_data)

    # Print the coefficients.
    #print("Coefficients: " + str(lr_model.coefficients))

    # Print the intercept.
    #print("Intercept: " + str(lr_model.intercept) + "\n")

    # Summarise the model and print out some evaluation metrics.
    training_summary = lr_model.summary
    print ("\n Training Results")
    # Print RMSE. 
    print("RMSE on training data: " + str(training_summary.rootMeanSquaredError))

    # Print R2.
    print("R2: " + str(training_summary.r2))

    # Let's evaluate the model against the test data.
    test_results = lr_model.evaluate(test_data)

    # And print the RMSE/R2. As expected, our RMSE and R2 are slightly worse when applying the testing set.
    print ("\n Test Results")
    print("RMSE on test data: " + str(test_results.rootMeanSquaredError))
    print("R2 on test data: " + str(test_results.r2))

# %%
linear_regression(vassembler_emp_under, splitfrac = [0.7,0.3])
linear_regression(vassembler_emp_over, splitfrac = [0.6,0.4])
linear_regression(vassembler_emp_normal, splitfrac = [0.6,0.4])
# Out:
# +-------+------------------+
# |summary|         Attrition|
# +-------+------------------+
# |  count|               339|
# |   mean|0.5103244837758112|
# | stddev|0.5006323347881733|
# |    min|                 0|
# |    max|                 1|
# +-------+------------------+
#
# +-------+------------------+
# |summary|         Attrition|
# +-------+------------------+
# |  count|               135|
# |   mean|0.4740740740740741|
# | stddev| 0.501187092745584|
# |    min|                 0|
# |    max|                 1|
# +-------+------------------+
#
#
#  Training Results
# RMSE on training data: 0.3788440057466699
# R2: 0.4256639919320111
#
#  Test Results
# RMSE on test data: 0.4378911954967514
# R2 on test data: 0.23093749098142868
# +-------+-------------------+
# |summary|          Attrition|
# +-------+-------------------+
# |  count|               1481|
# |   mean|0.49831195138419987|
# | stddev| 0.5001660399161926|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+------------------+
# |summary|         Attrition|
# +-------+------------------+
# |  count|               985|
# |   mean|0.5025380710659898|
# | stddev|0.5002475554056859|
# |    min|                 0|
# |    max|                 1|
# +-------+------------------+
#
#
#  Training Results
# RMSE on training data: 0.39543643983165255
# R2: 0.37451295889143754
#
#  Test Results
# RMSE on test data: 0.4017926433178345
# R2 on test data: 0.35423404750998533
# +-------+-------------------+
# |summary|          Attrition|
# +-------+-------------------+
# |  count|                879|
# |   mean|0.15130830489192265|
# | stddev|0.35855314708108127|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
# +-------+-------------------+
# |summary|          Attrition|
# +-------+-------------------+
# |  count|                591|
# |   mean|0.17597292724196278|
# | stddev|0.38111970530831657|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
#
#  Training Results
# RMSE on training data: 0.30904731729330936
# R2: 0.2562324307440901
#
#  Test Results
# RMSE on test data: 0.3346611164267801
# R2 on test data: 0.22763395613609894

# %%
def binomial_logistic_regression(data, splitfrac = [0.7,0.3], beta_coffecient = False, roc= False, precision_recall= False):
    # Split our data. Note that the new DataFrame is being used.
    #print('\n'.join(map(str, splitfrac))) 
    train_data, test_data = data.randomSplit(splitfrac)
    print("Training Dataset Count: " + str(train_data.count()))
    print("Test Dataset Count: " + str(test_data.count()))

    # Instantiate the model.
    lr_model = LogisticRegression(featuresCol='features',labelCol='Attrition')

    # Fit the model.
    lr_model = lr_model.fit(train_data)
    training_summary = lr_model.summary
    # And evaluate the model using the test data.
    results = lr_model.transform(test_data)
    if beta_coffecient:
        # Visualising the coefficients. Sort from lowest to highest.
        beta = np.sort(lr_model.coefficients)
        # Plot the data.
        plt.plot(beta)
        # Add a label to the data.
        plt.ylabel('Beta Coefficients')
        # Show the graph. 
        plt.show()
        
    if roc :
        # Convert DataFrame to Pandas DataFrame.
        # Convert the DataFrame to a Pandas DataFrame.
        ROC = training_summary.roc.toPandas()

        # Plot the true positive and false positive rates.
        plt.plot(ROC['FPR'],ROC['TPR'])

        # Define the labels.
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.title('ROC Curve')
        plt.show()

        # Print the AUC statistic. 
        print('Area Under the Curve: ' + str(training_summary.areaUnderROC))
    if precision_recall:
        # Convert DataFrame to Pandas DataFrame.
        pr = training_summary.pr.toPandas()
        # Plot model recall and precision.
        plt.plot(pr['recall'],pr['precision'])
        # Define the labels and show the graph. 
        plt.ylabel('Precision')
        plt.xlabel('Recall')
        plt.show()

# %%
binomial_logistic_regression(vassembler_emp_under, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
binomial_logistic_regression(vassembler_emp_over, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
binomial_logistic_regression(vassembler_emp_normal, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
# Out:
# Training Dataset Count: 281
# Test Dataset Count: 193
# Area Under the Curve: 0.8999999999999998
# Training Dataset Count: 1485
# Test Dataset Count: 981
# Area Under the Curve: 0.8761902947431071
# Training Dataset Count: 893
# Test Dataset Count: 577
# Area Under the Curve: 0.9035049356491319

# %%
vassembler = VectorAssembler(inputCols=["MonthlyRate", "NumCompaniesWorked", "OverTime", "PerformanceRating", "pdEmpb_Travel_Frequently", "Marketing", "Technical_Degree", "Education_Human_Resources", "pdEmp_Sales", "pdEmp_Dept_Human_Resources", "Laboratory_Technician", "Sales_Executive", "Sales_Representative", "Job_Human_Resources", "Marital_single"], outputCol="features")
vemp_normal_corr_columns = vassembler.transform(emp_normal)
vemp_normal_corr_columns = vemp_normal_corr_columns.select(['features', 'Attrition'])
vemp_normal_corr_columns.show(3)
# Out:
# +--------------------+---------+
# |            features|Attrition|
# +--------------------+---------+
# |(15,[0,1,2,3,8,11...|        1|
# |(15,[0,1,3,4],[24...|        0|
# |(15,[0,1,2,3,10,1...|        1|
# +--------------------+---------+
# only showing top 3 rows

# %%
binomial_logistic_regression(vemp_normal_corr_columns, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
# Out:
# Training Dataset Count: 834
# Test Dataset Count: 636
# Area Under the Curve: 0.7979258395925063

# %%
linear_regression(vemp_normal_corr_columns, splitfrac = [0.7,0.3])
# Out:
# +-------+------------------+
# |summary|         Attrition|
# +-------+------------------+
# |  count|              1024|
# |   mean|      0.1650390625|
# | stddev|0.3713971908219553|
# |    min|                 0|
# |    max|                 1|
# +-------+------------------+
#
# +-------+-------------------+
# |summary|          Attrition|
# +-------+-------------------+
# |  count|                446|
# |   mean|0.15246636771300448|
# | stddev|0.35987603045117317|
# |    min|                  0|
# |    max|                  1|
# +-------+-------------------+
#
#
#  Training Results
# RMSE on training data: 0.33866856526817857
# R2: 0.1676674674807066

# %%
vassembler = VectorAssembler(inputCols=["MonthlyRate", "NumCompaniesWorked", "OverTime", "PerformanceRating", "pdEmpb_Travel_Frequently", "Marketing", "Technical_Degree", "Education_Human_Resources", "pdEmp_Sales", "pdEmp_Dept_Human_Resources", "Laboratory_Technician", "Sales_Executive", "Sales_Representative", "Job_Human_Resources", "Marital_single"], outputCol="features")
vemp_normal_corr_columns_under = vassembler.transform(emp_under)
vemp_normal_corr_columns_under = vemp_normal_corr_columns_under.select(['features', 'Attrition'])
vemp_normal_corr_columns_under.show(3)

binomial_logistic_regression(vemp_normal_corr_columns_under, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
linear_regression(vemp_normal_corr_columns_under, splitfrac = [0.7,0.3])

# %%
vassembler = VectorAssembler(inputCols=["MonthlyRate", "NumCompaniesWorked", "OverTime", "PerformanceRating", "pdEmpb_Travel_Frequently", "Marketing", "Technical_Degree", "Education_Human_Resources", "pdEmp_Sales", "pdEmp_Dept_Human_Resources", "Laboratory_Technician", "Sales_Executive", "Sales_Representative", "Job_Human_Resources", "Marital_single"], outputCol="features")
vemp_normal_corr_columns_over = vassembler.transform(emp_over)
vemp_normal_corr_columns_over = vemp_normal_corr_columns_over.select(['features', 'Attrition'])
vemp_normal_corr_columns_over.show(3)

binomial_logistic_regression(vemp_normal_corr_columns_over, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
linear_regression(vemp_normal_corr_columns_over, splitfrac = [0.7,0.3])

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import StringIndexer, VectorIndexer
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.mllib.evaluation import BinaryClassificationMetrics as metric

# %%
assembler_features  = VectorAssembler(inputCols=["MonthlyRate", "NumCompaniesWorked", "OverTime", "PerformanceRating", "pdEmpb_Travel_Frequently", "Marketing", "Technical_Degree", "Education_Human_Resources", "pdEmp_Sales", "pdEmp_Dept_Human_Resources", "Laboratory_Technician", "Sales_Executive", "Sales_Representative", "Job_Human_Resources", "Marital_single"], outputCol="features")
labelIndexer = StringIndexer(inputCol='Attrition', outputCol="label")
tmp = [assembler_features, labelIndexer]
pipeline = Pipeline(stages=tmp)
allData = pipeline.fit(emp_over).transform(emp_over)
allData.cache()
trainingData, testData = allData.randomSplit([0.8,0.2], seed=0) # need to ensure same split for each time
print("Distribution of Pos and Neg in trainingData is: ", trainingData.groupBy("Attrition").count().take(3))

# %%
rf = RandomForestClassifier(labelCol='label', featuresCol='features',numTrees=200)
fit = rf.fit(trainingData)
transformed = fit.transform(testData)

# %%
training

results = transformed.select(['probability', 'label'])
## prepare score-label set
# Convert DataFrame to Pandas DataFrame.
# Convert the DataFrame to a Pandas DataFrame.
ROC = training_summary.roc.toPandas()

# Plot the true positive and false positive rates.
plt.plot(ROC['FPR'],ROC['TPR'])

# Define the labels.
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
binomial_logistic_regression(vassembler_emp_normal, splitfrac = [0.8,0.2], beta_coffecient = True, roc= True, precision_recall= True)
binomial_logistic_regression(vassembler_emp_normal, splitfrac = [0.6,0.4], beta_coffecient = True, roc= True, precision_recall= True)
binomial_logistic_regression(vassembler_emp_normal, splitfrac = [0.7,0.3], beta_coffecient = True, roc= True, precision_recall= True)
