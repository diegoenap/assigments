# %%
import findspark
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
findspark.init('/home/user/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('missing').getOrCreate()
from pyspark.ml.classification import LogisticRegression

# %%
df = spark.read.csv('Bank.csv',header=True,inferSchema=True)
Pdf=df.toPandas()

# %%
# The show method allows you visualise DataFrames in a tabular format. 
df.show()
# Out:
# +---+-----------+--------+-------------------+-------+-------+----+---------+-----+---+--------+--------+-----+--------+-----------+------------+--------------+-------------+---------+-----------+-------+
# |age|        job| marital|          education|default|housing|loan|  contact|month|day|duration|campaign|pdays|previous|   poutcome|emp var rate|cons price idx|cons conf idx|euribor3m|nr employed|Deposit|
# +---+-----------+--------+-------------------+-------+-------+----+---------+-----+---+--------+--------+-----+--------+-----------+------------+--------------+-------------+---------+-----------+-------+
# | 56|  housemaid| married|           basic.4y|     no|     no|  no|telephone|  may|mon|     261|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 57|   services| married|        high.school|unknown|     no|  no|telephone|  may|mon|     149|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 37|   services| married|        high.school|     no|    yes|  no|telephone|  may|mon|     226|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 40|     admin.| married|           basic.6y|     no|     no|  no|telephone|  may|mon|     151|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 56|   services| married|        high.school|     no|     no| yes|telephone|  may|mon|     307|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 45|   services| married|           basic.9y|unknown|     no|  no|telephone|  may|mon|     198|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 59|     admin.| married|professional.course|     no|     no|  no|telephone|  may|mon|     139|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 41|blue-collar| married|            unknown|unknown|     no|  no|telephone|  may|mon|     217|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 24| technician|  single|professional.course|     no|    yes|  no|telephone|  may|mon|     380|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 25|   services|  single|        high.school|     no|    yes|  no|telephone|  may|mon|      50|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 41|blue-collar| married|            unknown|unknown|     no|  no|telephone|  may|mon|      55|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 25|   services|  single|        high.school|     no|    yes|  no|telephone|  may|mon|     222|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 29|blue-collar|  single|        high.school|     no|     no| yes|telephone|  may|mon|     137|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 57|  housemaid|divorced|           basic.4y|     no|    yes|  no|telephone|  may|mon|     293|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 35|blue-collar| married|           basic.6y|     no|    yes|  no|telephone|  may|mon|     146|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 54|    retired| married|           basic.9y|unknown|    yes| yes|telephone|  may|mon|     174|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 35|blue-collar| married|           basic.6y|     no|    yes|  no|telephone|  may|mon|     312|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 46|blue-collar| married|           basic.6y|unknown|    yes| yes|telephone|  may|mon|     440|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 50|blue-collar| married|           basic.9y|     no|    yes| yes|telephone|  may|mon|     353|    null|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# | 39| management|  single|           basic.9y|unknown|     no|  no|telephone|  may|mon|     195|       1|  999|       0|nonexistent|         1.1|        93.994|        -36.4|    4.857|     5191.0|     no|
# +---+-----------+--------+-------------------+-------+-------+----+---------+-----+---+--------+--------+-----+--------+-----------+------------+--------------+-------------+---------+-----------+-------+
# only showing top 20 rows

# %%
Pdf.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month  day   ...     campaign  pdays  previous     poutcome emp var rate  \
# 0   may  mon   ...          1.0    999         0  nonexistent          1.1
# 1   may  mon   ...          1.0    999         0  nonexistent          1.1
# 2   may  mon   ...          1.0    999         0  nonexistent          1.1
# 3   may  mon   ...          1.0    999         0  nonexistent          1.1
# 4   may  mon   ...          1.0    999         0  nonexistent          1.1
#
#    cons price idx  cons conf idx  euribor3m  nr employed  Deposit
# 0          93.994          -36.4      4.857       5191.0       no
# 1          93.994          -36.4      4.857       5191.0       no
# 2          93.994          -36.4      4.857       5191.0       no
# 3          93.994          -36.4      4.857       5191.0       no
# 4          93.994          -36.4      4.857       5191.0       no
#
# [5 rows x 21 columns]

# %%
# Print schema allows us to visualise the data structure at a high level. 
df.printSchema()

# We can also use head to print a specific amount of rows, so we can get a better understanding of the data points. 
print(df.head(2))
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- emp var rate: double (nullable = true)
#  |-- cons price idx: double (nullable = true)
#  |-- cons conf idx: double (nullable = true)
#  |-- euribor3m: double (nullable = true)
#  |-- nr employed: double (nullable = true)
#  |-- Deposit: string (nullable = true)
#
# [Row(age=56, job='housemaid', marital='married', education='basic.4y', default='no', housing='no', loan='no', contact='telephone', month='may', day='mon', duration=261, campaign=1, pdays=999, previous=0, poutcome='nonexistent', emp var rate=1.1, cons price idx=93.994, cons conf idx=-36.4, euribor3m=4.857, nr employed=5191.0, Deposit='no'), Row(age=57, job='services', marital='married', education='high.school', default='unknown', housing='no', loan='no', contact='telephone', month='may', day='mon', duration=149, campaign=1, pdays=999, previous=0, poutcome='nonexistent', emp var rate=1.1, cons price idx=93.994, cons conf idx=-36.4, euribor3m=4.857, nr employed=5191.0, Deposit='no')]

# %%
# We can use the describe method get some general statistics on our data. 
df.select('Deposit').describe().show()
# Out:
# +-------+-------+
# |summary|Deposit|
# +-------+-------+
# |  count|  41188|
# |   mean|   null|
# | stddev|   null|
# |    min|     no|
# |    max|    yes|
# +-------+-------+

# %%
df.count()
# Out:
# 41188

# %%
Pdf.head(25)
# Out:
#     age          job   marital            education  default housing loan  \
# 0    56    housemaid   married             basic.4y       no      no   no
# 1    57     services   married          high.school  unknown      no   no
# 2    37     services   married          high.school       no     yes   no
# 3    40       admin.   married             basic.6y       no      no   no
# 4    56     services   married          high.school       no      no  yes
# 5    45     services   married             basic.9y  unknown      no   no
# 6    59       admin.   married  professional.course       no      no   no
# 7    41  blue-collar   married              unknown  unknown      no   no
# 8    24   technician    single  professional.course       no     yes   no
# 9    25     services    single          high.school       no     yes   no
# 10   41  blue-collar   married              unknown  unknown      no   no
# 11   25     services    single          high.school       no     yes   no
# 12   29  blue-collar    single          high.school       no      no  yes
# 13   57    housemaid  divorced             basic.4y       no     yes   no
# 14   35  blue-collar   married             basic.6y       no     yes   no
# 15   54      retired   married             basic.9y  unknown     yes  yes
# 16   35  blue-collar   married             basic.6y       no     yes   no
# 17   46  blue-collar   married             basic.6y  unknown     yes  yes
# 18   50  blue-collar   married             basic.9y       no     yes  yes
# 19   39   management    single             basic.9y  unknown      no   no
# 20   30   unemployed   married          high.school       no      no   no
# 21   55  blue-collar   married             basic.4y  unknown     yes   no
# 22   55      retired    single          high.school       no     yes   no
# 23   41   technician    single          high.school       no     yes   no
# 24   37       admin.   married          high.school       no     yes   no
#
#       contact month  day   ...     campaign  pdays  previous     poutcome  \
# 0   telephone   may  mon   ...          1.0    999         0  nonexistent
# 1   telephone   may  mon   ...          1.0    999         0  nonexistent
# 2   telephone   may  mon   ...          1.0    999         0  nonexistent
# 3   telephone   may  mon   ...          1.0    999         0  nonexistent
# 4   telephone   may  mon   ...          1.0    999         0  nonexistent
# 5   telephone   may  mon   ...          1.0    999         0  nonexistent
# 6   telephone   may  mon   ...          1.0    999         0  nonexistent
# 7   telephone   may  mon   ...          1.0    999         0  nonexistent
# 8   telephone   may  mon   ...          1.0    999         0  nonexistent
# 9   telephone   may  mon   ...          1.0    999         0  nonexistent
# 10  telephone   may  mon   ...          1.0    999         0  nonexistent
# 11  telephone   may  mon   ...          1.0    999         0  nonexistent
# 12  telephone   may  mon   ...          1.0    999         0  nonexistent
# 13  telephone   may  mon   ...          1.0    999         0  nonexistent
# 14  telephone   may  mon   ...          1.0    999         0  nonexistent
# 15  telephone   may  mon   ...          1.0    999         0  nonexistent
# 16  telephone   may  mon   ...          1.0    999         0  nonexistent
# 17  telephone   may  mon   ...          1.0    999         0  nonexistent
# 18  telephone   may  mon   ...          NaN    999         0  nonexistent
# 19  telephone   may  mon   ...          1.0    999         0  nonexistent
# 20  telephone   may  mon   ...          1.0    999         0  nonexistent
# 21  telephone   may  mon   ...          1.0    999         0  nonexistent
# 22  telephone   may  mon   ...          1.0    999         0  nonexistent
# 23  telephone   may  mon   ...          1.0    999         0  nonexistent
# 24  telephone   may  mon   ...          1.0    999         0  nonexistent
#
#    emp var rate  cons price idx  cons conf idx  euribor3m  nr employed  \
# 0           1.1          93.994          -36.4      4.857       5191.0
# 1           1.1          93.994          -36.4      4.857       5191.0
# 2           1.1          93.994          -36.4      4.857       5191.0
# 3           1.1          93.994          -36.4      4.857       5191.0
# 4           1.1          93.994          -36.4      4.857       5191.0
# 5           1.1          93.994          -36.4      4.857       5191.0
# 6           1.1          93.994          -36.4      4.857       5191.0
# 7           1.1          93.994          -36.4      4.857       5191.0
# 8           1.1          93.994          -36.4      4.857       5191.0
# 9           1.1          93.994          -36.4      4.857       5191.0
# 10          1.1          93.994          -36.4      4.857       5191.0
# 11          1.1          93.994          -36.4      4.857       5191.0
# 12          1.1          93.994          -36.4      4.857       5191.0
# 13          1.1          93.994          -36.4      4.857       5191.0
# 14          1.1          93.994          -36.4      4.857       5191.0
# 15          1.1          93.994          -36.4      4.857       5191.0
# 16          1.1          93.994          -36.4      4.857       5191.0
# 17          1.1          93.994          -36.4      4.857       5191.0
# 18          1.1          93.994          -36.4      4.857       5191.0
# 19          1.1          93.994          -36.4      4.857       5191.0
# 20          1.1          93.994          -36.4      4.857       5191.0
# 21          1.1          93.994          -36.4      4.857       5191.0
# 22          1.1          93.994          -36.4      4.857       5191.0
# 23          1.1          93.994          -36.4      4.857       5191.0
# 24          1.1          93.994          -36.4      4.857       5191.0
#
#     Deposit
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# 5        no
# 6        no
# 7        no
# 8        no
# 9        no
# 10       no
# 11       no
# 12       no
# 13       no
# 14       no
# 15       no
# 16       no
# 17       no
# 18       no
# 19       no
# 20       no
# 21       no
# 22       no
# 23       no
# 24       no
#
# [25 rows x 21 columns]

# %%
# For integer type features, you may want to replace the null value the average of that feature.
# Let's see how that's done using balance as an example.
from pyspark.sql.functions import mean

# Let's find the average. But the problem is, how do we get that information out of the DataFrame?
mean_campaign = df.select(mean('campaign')).show()
# Out:
# +-----------------+
# |    avg(campaign)|
# +-----------------+
# |2.567633847274493|
# +-----------------+

# %%
Pdf['campaign']=Pdf['campaign'].fillna(Pdf['campaign'].mean())

# %%
Pdf.head(20)
# Out:
#     age          job   marital            education  default housing loan  \
# 0    56    housemaid   married             basic.4y       no      no   no
# 1    57     services   married          high.school  unknown      no   no
# 2    37     services   married          high.school       no     yes   no
# 3    40       admin.   married             basic.6y       no      no   no
# 4    56     services   married          high.school       no      no  yes
# 5    45     services   married             basic.9y  unknown      no   no
# 6    59       admin.   married  professional.course       no      no   no
# 7    41  blue-collar   married              unknown  unknown      no   no
# 8    24   technician    single  professional.course       no     yes   no
# 9    25     services    single          high.school       no     yes   no
# 10   41  blue-collar   married              unknown  unknown      no   no
# 11   25     services    single          high.school       no     yes   no
# 12   29  blue-collar    single          high.school       no      no  yes
# 13   57    housemaid  divorced             basic.4y       no     yes   no
# 14   35  blue-collar   married             basic.6y       no     yes   no
# 15   54      retired   married             basic.9y  unknown     yes  yes
# 16   35  blue-collar   married             basic.6y       no     yes   no
# 17   46  blue-collar   married             basic.6y  unknown     yes  yes
# 18   50  blue-collar   married             basic.9y       no     yes  yes
# 19   39   management    single             basic.9y  unknown      no   no
#
#       contact month  day   ...     campaign  pdays  previous     poutcome  \
# 0   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 1   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 2   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 3   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 4   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 5   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 6   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 7   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 8   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 9   telephone   may  mon   ...     1.000000    999         0  nonexistent
# 10  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 11  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 12  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 13  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 14  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 15  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 16  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 17  telephone   may  mon   ...     1.000000    999         0  nonexistent
# 18  telephone   may  mon   ...     2.567634    999         0  nonexistent
# 19  telephone   may  mon   ...     1.000000    999         0  nonexistent
#
#    emp var rate  cons price idx  cons conf idx  euribor3m  nr employed  \
# 0           1.1          93.994          -36.4      4.857       5191.0
# 1           1.1          93.994          -36.4      4.857       5191.0
# 2           1.1          93.994          -36.4      4.857       5191.0
# 3           1.1          93.994          -36.4      4.857       5191.0
# 4           1.1          93.994          -36.4      4.857       5191.0
# 5           1.1          93.994          -36.4      4.857       5191.0
# 6           1.1          93.994          -36.4      4.857       5191.0
# 7           1.1          93.994          -36.4      4.857       5191.0
# 8           1.1          93.994          -36.4      4.857       5191.0
# 9           1.1          93.994          -36.4      4.857       5191.0
# 10          1.1          93.994          -36.4      4.857       5191.0
# 11          1.1          93.994          -36.4      4.857       5191.0
# 12          1.1          93.994          -36.4      4.857       5191.0
# 13          1.1          93.994          -36.4      4.857       5191.0
# 14          1.1          93.994          -36.4      4.857       5191.0
# 15          1.1          93.994          -36.4      4.857       5191.0
# 16          1.1          93.994          -36.4      4.857       5191.0
# 17          1.1          93.994          -36.4      4.857       5191.0
# 18          1.1          93.994          -36.4      4.857       5191.0
# 19          1.1          93.994          -36.4      4.857       5191.0
#
#     Deposit
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# 5        no
# 6        no
# 7        no
# 8        no
# 9        no
# 10       no
# 11       no
# 12       no
# 13       no
# 14       no
# 15       no
# 16       no
# 17       no
# 18       no
# 19       no
#
# [20 rows x 21 columns]

# %%
#Pie Plot

# %%
# plot data
colors = ['yellowgreen','lightskyblue']
Pdf['Deposit'].value_counts().plot(kind='pie',title='Termdeposit',colors=colors)
plt.show()

# %%
# Boxplot for 'age'
g = sns.boxplot(x=Pdf["duration"])

# %%
# Distribution of Age
sns.distplot(Pdf.age, bins=100)

# %%
sns.distplot(Pdf.duration, bins=100)

# %%
# Scatterplot showing age and balance
Pdf.plot(kind='scatter', x='age', y='emp var rate');

# %%
# Scatterplot showing age and balance
Pdf.plot(kind='scatter', x='duration', y='campaign');

# %%
#Histogram

# %%
Pdf['duration'].plot(kind='hist',bins=100)
plt.xlabel('deposit')
# Out:
# Text(0.5,0,'deposit')

# %%
#Histogram

# %%
plt.figure();

Pdf.plot.hist(stacked=True, bins=20)

# %%
#Horizontal and cumulative histogram

# %%
plt.figure();
Pdf['duration'].plot.hist(orientation='horizontal', cumulative=True)

# %%
#Boxplot

# %%
Pdf = pd.DataFrame(np.random.rand(4,4), columns=['age', 'loan', 'Duration', 'Deposit'])

Pdf.plot.box()

# %%
Pdf=df.toPandas()

# %%
Pdf.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month  day   ...     campaign  pdays  previous     poutcome emp var rate  \
# 0   may  mon   ...          1.0    999         0  nonexistent          1.1
# 1   may  mon   ...          1.0    999         0  nonexistent          1.1
# 2   may  mon   ...          1.0    999         0  nonexistent          1.1
# 3   may  mon   ...          1.0    999         0  nonexistent          1.1
# 4   may  mon   ...          1.0    999         0  nonexistent          1.1
#
#    cons price idx  cons conf idx  euribor3m  nr employed  Deposit
# 0          93.994          -36.4      4.857       5191.0       no
# 1          93.994          -36.4      4.857       5191.0       no
# 2          93.994          -36.4      4.857       5191.0       no
# 3          93.994          -36.4      4.857       5191.0       no
# 4          93.994          -36.4      4.857       5191.0       no
#
# [5 rows x 21 columns]

# %%
Pdf.drop(['job','marital','education','cons conf idx','housing'],axis=1)
# Out:
#        age  default     loan    contact month  day  duration  campaign  pdays  \
# 0       56       no       no  telephone   may  mon       261       1.0    999
# 1       57  unknown       no  telephone   may  mon       149       1.0    999
# 2       37       no       no  telephone   may  mon       226       1.0    999
# 3       40       no       no  telephone   may  mon       151       1.0    999
# 4       56       no      yes  telephone   may  mon       307       1.0    999
# 5       45  unknown       no  telephone   may  mon       198       1.0    999
# 6       59       no       no  telephone   may  mon       139       1.0    999
# 7       41  unknown       no  telephone   may  mon       217       1.0    999
# 8       24       no       no  telephone   may  mon       380       1.0    999
# 9       25       no       no  telephone   may  mon        50       1.0    999
# 10      41  unknown       no  telephone   may  mon        55       1.0    999
# 11      25       no       no  telephone   may  mon       222       1.0    999
# 12      29       no      yes  telephone   may  mon       137       1.0    999
# 13      57       no       no  telephone   may  mon       293       1.0    999
# 14      35       no       no  telephone   may  mon       146       1.0    999
# 15      54  unknown      yes  telephone   may  mon       174       1.0    999
# 16      35       no       no  telephone   may  mon       312       1.0    999
# 17      46  unknown      yes  telephone   may  mon       440       1.0    999
# 18      50       no      yes  telephone   may  mon       353       NaN    999
# 19      39  unknown       no  telephone   may  mon       195       1.0    999
# 20      30       no       no  telephone   may  mon        38       1.0    999
# 21      55  unknown       no  telephone   may  mon       262       1.0    999
# 22      55       no       no  telephone   may  mon       342       1.0    999
# 23      41       no       no  telephone   may  mon       181       1.0    999
# 24      37       no       no  telephone   may  mon       172       1.0    999
# 25      35       no      yes  telephone   may  mon        99       1.0    999
# 26      59       no       no  telephone   may  mon        93       1.0    999
# 27      39  unknown       no  telephone   may  mon       233       1.0    999
# 28      54  unknown       no  telephone   may  mon       255       2.0    999
# 29      55  unknown  unknown  telephone   may  mon       362       1.0    999
# ...    ...      ...      ...        ...   ...  ...       ...       ...    ...
# 41158   35       no       no   cellular   nov  tue       363       1.0    999
# 41159   35       no       no   cellular   nov  tue       514       1.0      9
# 41160   33       no       no   cellular   nov  tue       843       1.0    999
# 41161   33       no       no   cellular   nov  tue       510       1.0    999
# 41162   60       no       no   cellular   nov  tue       347       2.0      4
# 41163   35       no       no   cellular   nov  tue       385       3.0      4
# 41164   54       no       no   cellular   nov  tue      1868       2.0     10
# 41165   38       no       no   cellular   nov  wed       403       2.0    999
# 41166   32       no       no  telephone   nov  wed       651       1.0    999
# 41167   32       no       no   cellular   nov  wed       236       3.0    999
# 41168   38       no       no   cellular   nov  wed       144       2.0    999
# 41169   62       no       no   cellular   nov  wed       154       5.0    999
# 41170   40       no       no   cellular   nov  wed       293       2.0    999
# 41171   33       no       no  telephone   nov  thu       112       1.0    999
# 41172   31       no       no   cellular   nov  thu       353       1.0    999
# 41173   62       no       no   cellular   nov  thu       329       1.0    999
# 41174   62       no       no   cellular   nov  thu       208       1.0      1
# 41175   34       no       no   cellular   nov  thu       180       1.0    999
# 41176   38       no      yes   cellular   nov  thu       360       1.0    999
# 41177   57       no       no   cellular   nov  thu       124       6.0    999
# 41178   62       no       no   cellular   nov  thu       483       2.0      6
# 41179   64       no       no   cellular   nov  fri       151       3.0    999
# 41180   36       no       no   cellular   nov  fri       254       2.0    999
# 41181   37       no       no   cellular   nov  fri       281       1.0    999
# 41182   29       no       no   cellular   nov  fri       112       1.0      9
# 41183   73       no       no   cellular   nov  fri       334       1.0    999
# 41184   46       no       no   cellular   nov  fri       383       1.0    999
# 41185   56       no       no   cellular   nov  fri       189       2.0    999
# 41186   44       no       no   cellular   nov  fri       442       1.0    999
# 41187   74       no       no   cellular   nov  fri       239       3.0    999
#
#        previous     poutcome  emp var rate  cons price idx  euribor3m  \
# 0             0  nonexistent           1.1          93.994      4.857
# 1             0  nonexistent           1.1          93.994      4.857
# 2             0  nonexistent           1.1          93.994      4.857
# 3             0  nonexistent           1.1          93.994      4.857
# 4             0  nonexistent           1.1          93.994      4.857
# 5             0  nonexistent           1.1          93.994      4.857
# 6             0  nonexistent           1.1          93.994      4.857
# 7             0  nonexistent           1.1          93.994      4.857
# 8             0  nonexistent           1.1          93.994      4.857
# 9             0  nonexistent           1.1          93.994      4.857
# 10            0  nonexistent           1.1          93.994      4.857
# 11            0  nonexistent           1.1          93.994      4.857
# 12            0  nonexistent           1.1          93.994      4.857
# 13            0  nonexistent           1.1          93.994      4.857
# 14            0  nonexistent           1.1          93.994      4.857
# 15            0  nonexistent           1.1          93.994      4.857
# 16            0  nonexistent           1.1          93.994      4.857
# 17            0  nonexistent           1.1          93.994      4.857
# 18            0  nonexistent           1.1          93.994      4.857
# 19            0  nonexistent           1.1          93.994      4.857
# 20            0  nonexistent           1.1          93.994      4.857
# 21            0  nonexistent           1.1          93.994      4.857
# 22            0  nonexistent           1.1          93.994      4.857
# 23            0  nonexistent           1.1          93.994      4.857
# 24            0  nonexistent           1.1          93.994      4.857
# 25            0  nonexistent           1.1          93.994      4.857
# 26            0  nonexistent           1.1          93.994      4.857
# 27            0  nonexistent           1.1          93.994      4.857
# 28            0  nonexistent           1.1          93.994      4.857
# 29            0  nonexistent           1.1          93.994      4.857
# ...         ...          ...           ...             ...        ...
# 41158         0  nonexistent          -1.1          94.767      1.035
# 41159         4      success          -1.1          94.767      1.035
# 41160         0  nonexistent          -1.1          94.767      1.035
# 41161         1      failure          -1.1          94.767      1.035
# 41162         1      success          -1.1          94.767      1.035
# 41163         2      success          -1.1          94.767      1.035
# 41164         1      success          -1.1          94.767      1.035
# 41165         0  nonexistent          -1.1          94.767      1.030
# 41166         1      failure          -1.1          94.767      1.030
# 41167         0  nonexistent          -1.1          94.767      1.030
# 41168         0  nonexistent          -1.1          94.767      1.030
# 41169         0  nonexistent          -1.1          94.767      1.030
# 41170         4      failure          -1.1          94.767      1.030
# 41171         0  nonexistent          -1.1          94.767      1.031
# 41172         0  nonexistent          -1.1          94.767      1.031
# 41173         2      failure          -1.1          94.767      1.031
# 41174         6      success          -1.1          94.767      1.031
# 41175         2      failure          -1.1          94.767      1.031
# 41176         0  nonexistent          -1.1          94.767      1.031
# 41177         0  nonexistent          -1.1          94.767      1.031
# 41178         3      success          -1.1          94.767      1.031
# 41179         0  nonexistent          -1.1          94.767      1.028
# 41180         0  nonexistent          -1.1          94.767      1.028
# 41181         0  nonexistent          -1.1          94.767      1.028
# 41182         1      success          -1.1          94.767      1.028
# 41183         0  nonexistent          -1.1          94.767      1.028
# 41184         0  nonexistent          -1.1          94.767      1.028
# 41185         0  nonexistent          -1.1          94.767      1.028
# 41186         0  nonexistent          -1.1          94.767      1.028
# 41187         1      failure          -1.1          94.767      1.028
#
#        nr employed Deposit
# 0           5191.0      no
# 1           5191.0      no
# 2           5191.0      no
# 3           5191.0      no
# 4           5191.0      no
# 5           5191.0      no
# 6           5191.0      no
# 7           5191.0      no
# 8           5191.0      no
# 9           5191.0      no
# 10          5191.0      no
# 11          5191.0      no
# 12          5191.0      no
# 13          5191.0      no
# 14          5191.0      no
# 15          5191.0      no
# 16          5191.0      no
# 17          5191.0      no
# 18          5191.0      no
# 19          5191.0      no
# 20          5191.0      no
# 21          5191.0      no
# 22          5191.0      no
# 23          5191.0      no
# 24          5191.0      no
# 25          5191.0      no
# 26          5191.0      no
# 27          5191.0      no
# 28          5191.0      no
# 29          5191.0      no
# ...            ...     ...
# 41158       4963.6     yes
# 41159       4963.6     yes
# 41160       4963.6     yes
# 41161       4963.6      no
# 41162       4963.6      no
# 41163       4963.6     yes
# 41164       4963.6     yes
# 41165       4963.6     yes
# 41166       4963.6     yes
# 41167       4963.6      no
# 41168       4963.6      no
# 41169       4963.6      no
# 41170       4963.6      no
# 41171       4963.6     yes
# 41172       4963.6     yes
# 41173       4963.6     yes
# 41174       4963.6     yes
# 41175       4963.6      no
# 41176       4963.6      no
# 41177       4963.6      no
# 41178       4963.6     yes
# 41179       4963.6      no
# 41180       4963.6      no
# 41181       4963.6     yes
# 41182       4963.6      no
# 41183       4963.6     yes
# 41184       4963.6      no
# 41185       4963.6      no
# 41186       4963.6     yes
# 41187       4963.6      no
#
# [41188 rows x 16 columns]

# %%
sdf = spark.createDataFrame(Pdf)

# %%
sdf=sdf.drop('job','marital','education','cons conf idx','housing')

# %%
sdf.show()
# Out:
# +---+-------+----+---------+-----+---+--------+--------+-----+--------+-----------+------------+--------------+---------+-----------+-------+
# |age|default|loan|  contact|month|day|duration|campaign|pdays|previous|   poutcome|emp var rate|cons price idx|euribor3m|nr employed|Deposit|
# +---+-------+----+---------+-----+---+--------+--------+-----+--------+-----------+------------+--------------+---------+-----------+-------+
# | 56|     no|  no|telephone|  may|mon|     261|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 57|unknown|  no|telephone|  may|mon|     149|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 37|     no|  no|telephone|  may|mon|     226|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 40|     no|  no|telephone|  may|mon|     151|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 56|     no| yes|telephone|  may|mon|     307|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 45|unknown|  no|telephone|  may|mon|     198|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 59|     no|  no|telephone|  may|mon|     139|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 41|unknown|  no|telephone|  may|mon|     217|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 24|     no|  no|telephone|  may|mon|     380|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 25|     no|  no|telephone|  may|mon|      50|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 41|unknown|  no|telephone|  may|mon|      55|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 25|     no|  no|telephone|  may|mon|     222|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 29|     no| yes|telephone|  may|mon|     137|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 57|     no|  no|telephone|  may|mon|     293|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 35|     no|  no|telephone|  may|mon|     146|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 54|unknown| yes|telephone|  may|mon|     174|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 35|     no|  no|telephone|  may|mon|     312|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 46|unknown| yes|telephone|  may|mon|     440|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 50|     no| yes|telephone|  may|mon|     353|     NaN|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# | 39|unknown|  no|telephone|  may|mon|     195|     1.0|  999|       0|nonexistent|         1.1|        93.994|    4.857|     5191.0|     no|
# +---+-------+----+---------+-----+---+--------+--------+-----+--------+-----------+------------+--------------+---------+-----------+-------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import (VectorAssembler, StringIndexer, VectorIndexer, OneHotEncoder)

# %%
# First create a string indexer which converts every string into a number, such as male = 0 and female = 1.
# A number will be assigned to every category in the column.
loan_indexer = StringIndexer(inputCol='loan',outputCol='loanIndex')
contact_indexer = StringIndexer(inputCol='contact',outputCol='contactIndex')
month_indexer = StringIndexer(inputCol='month',outputCol='monthIndex')
day_indexer = StringIndexer(inputCol='day',outputCol='day_Index')
default_indexer = StringIndexer(inputCol='default',outputCol='defaultIndex')
poutcome_indexer = StringIndexer(inputCol='poutcome',outputCol='poutcomeIndex')
Deposit_indexer = StringIndexer(inputCol='Deposit',outputCol='label')

# %%
# Now we can one hot encode these numbers. This converts the various outputs into a single vector.
# Multiple columns are collapsed into one. 
# This makes it easier to process when you have multiple classes.
loan_encoder = OneHotEncoder(inputCol='loanIndex',outputCol='loanVec')
poutcome_encoder = OneHotEncoder(inputCol='poutcomeIndex',outputCol='poutcomeVec')
contact_encoder = OneHotEncoder(inputCol='contactIndex',outputCol='contactVec')
month_encoder = OneHotEncoder(inputCol='monthIndex',outputCol='monthVec')
day_encoder = OneHotEncoder(inputCol='day_Index',outputCol='dayVec')
default_encoder = OneHotEncoder(inputCol='defaultIndex',outputCol='defaultVec')

# %%
# And finally, using vector assembler to turn all of these columns into one column (named features).
assembler = VectorAssembler(inputCols=['loanVec','contactVec','monthVec','defaultVec',
                                       'dayVec','poutcomeVec',
                                       'age', 'duration', 'campaign', 'pdays',
                                       'previous','emp var rate','euribor3m','nr employed'], outputCol="Bankmarket")

# %%
from pyspark.ml import Pipeline

# Then go through our steps. It's essentially sequential to the above.
pipeline = Pipeline(stages=[loan_indexer, contact_indexer, month_indexer, day_indexer,
                            default_indexer, poutcome_indexer, Deposit_indexer,loan_encoder,
                            contact_encoder, month_encoder ,day_encoder,default_encoder,
                           poutcome_encoder, assembler])

# Now that we've got a number of steps, let's apply it to the DataFrame.
pipeline_model = pipeline.fit(sdf)

# Incorporate results into a new DataFrame.
pipe_df = pipeline_model.transform(sdf)

# Remove all variables other than features and label. 
pipe_df = pipe_df.select('label', 'Bankmarket')

# %%
from pyspark.ml.classification import LogisticRegression

# Split our data. Note that the new DataFrame is being used.
train_data, test_data = pipe_df.randomSplit([0.7,0.3])
print("Training Dataset Count: " + str(train_data.count()))
print("Test Dataset Count: " + str(test_data.count()))

# Instantiate the model.
lr_model = LogisticRegression(featuresCol='Bankmarket',labelCol='label')

# Fit the model.
lr_model = lr_model.fit(train_data)

# And evaluate the model using the test data.
results = lr_model.transform(test_data)
# Out:
# Training Dataset Count: 28815
# Test Dataset Count: 12373

# %%
# Visualising the coefficients. Sort from lowest to highest.
beta = np.sort(lr_model.coefficients)

# Plot the data.
plt.plot(beta)

# Add a label to the data.
plt.ylabel('Beta Coefficients')

# Show the graph. 
plt.show()

# %%
# Let's get a summary of the data.
training_summary = lr_model.summary

# Convert the DataFrame to a Pandas DataFrame.
ROC = training_summary.roc.toPandas()

# Plot the true positive and false positive rates.
plt.plot(ROC['FPR'],ROC['TPR'])

# Define the labels.
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve')
plt.show()

# Print the AUC statistic. 
print('Area Under the Curve: ' + str(training_summary.areaUnderROC))
# Out:
# Area Under the Curve: 0.5

# %%
# Convert DataFrame to Pandas DataFrame.
pr = training_summary.pr.toPandas()

# Plot model recall and precision.
plt.plot(pr['recall'],pr['precision'])

# Define the labels and show the graph. 
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %%
sdf.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- default: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- duration: long (nullable = true)
#  |-- campaign: double (nullable = true)
#  |-- pdays: long (nullable = true)
#  |-- previous: long (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- emp var rate: double (nullable = true)
#  |-- cons price idx: double (nullable = true)
#  |-- euribor3m: double (nullable = true)
#  |-- nr employed: double (nullable = true)
#  |-- Deposit: string (nullable = true)

# %%
sdf.columns
# Out:
# ['age',
#  'default',
#  'loan',
#  'contact',
#  'month',
#  'day',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp var rate',
#  'cons price idx',
#  'euribor3m',
#  'nr employed',
#  'Deposit']

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(inputCols = ['age','duration','pdays','previous','campaign','emp var rate','cons price idx','euribor3m','nr employed'], outputCol = 'features')

# %%
output = assembler.transform(sdf)

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol = 'Deposit', outputCol = 'DepositIndex')
outputFixed = indexer.fit(output).transform(output)
outputFixed.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- default: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- day: string (nullable = true)
#  |-- duration: long (nullable = true)
#  |-- campaign: double (nullable = true)
#  |-- pdays: long (nullable = true)
#  |-- previous: long (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- emp var rate: double (nullable = true)
#  |-- cons price idx: double (nullable = true)
#  |-- euribor3m: double (nullable = true)
#  |-- nr employed: double (nullable = true)
#  |-- Deposit: string (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- DepositIndex: double (nullable = true)

# %%
final_df = outputFixed.select('features', 'DepositIndex')
final_df.show(3)
# Out:
# +--------------------+------------+
# |            features|DepositIndex|
# +--------------------+------------+
# |[56.0,261.0,999.0...|         0.0|
# |[57.0,149.0,999.0...|         0.0|
# |[37.0,226.0,999.0...|         0.0|
# +--------------------+------------+
# only showing top 3 rows

# %%
train, test = final_df.randomSplit([0.7, 0.3])

# %%
from pyspark.ml.classification import (DecisionTreeClassifier, RandomForestClassifier)
from pyspark.ml import Pipeline

dt = DecisionTreeClassifier(labelCol = 'DepositIndex', featuresCol = 'features')
rf = RandomForestClassifier(labelCol = 'DepositIndex', featuresCol = 'features')
gb = GBTClassifier(labelCol = 'DepositIndex', featuresCol = 'features')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2a406ddb1c1b> in <module>()
#       4 dt = DecisionTreeClassifier(labelCol = 'DepositIndex', featuresCol = 'features')
#       5 rf = RandomForestClassifier(labelCol = 'DepositIndex', featuresCol = 'features')
# ----> 6 gb = GBTClassifier(labelCol = 'DepositIndex', featuresCol = 'features')
#
# NameError: name 'GBTClassifier' is not defined

# %%
dt_model = dt.fit(train)
rf_model = rf.fit(train)
gb_model = gb.fit(train)

# %%
dt_predictions = dt_model.transform(test)
rf_predictions = rf_model.transform(test)
gb_predictions = gb_model.transform(test)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

multi_evaluator = MulticlassClassificationEvaluator(labelCol = 'DepositIndex', metricName = 'accuracy')
print('Decision Tree Accu:', multi_evaluator.evaluate(dt_predictions))

# %%
print('Random Forest Accu:', multi_evaluator.evaluate(rf_predictions))

# %%
print('Gradient-boosted Trees Accu:', multi_evaluator.evaluate(gb_predictions))
